# %% [markdown]
# # NLTK

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import pandas as pd
from string import punctuation
from nltk.tag import StanfordNERTagger

# %%
df = pd.read_csv('result.tar.gz', compression='gzip', sep='\t', error_bad_lines=False)
# Out:
# b'Skipping line 37039: expected 12 fields, saw 15\nSkipping line 45611: expected 12 fields, saw 15\n'
# b'Skipping line 354339: expected 12 fields, saw 18\nSkipping line 360804: expected 12 fields, saw 102\nSkipping line 360819: expected 12 fields, saw 78\nSkipping line 379126: expected 12 fields, saw 14\nSkipping line 444446: expected 12 fields, saw 16\nSkipping line 449079: expected 12 fields, saw 16\nSkipping line 450250: expected 12 fields, saw 15\n'
# b'Skipping line 481374: expected 12 fields, saw 18\nSkipping line 510619: expected 12 fields, saw 20\nSkipping line 512271: expected 12 fields, saw 14\nSkipping line 514317: expected 12 fields, saw 15\nSkipping line 519707: expected 12 fields, saw 40\n'
# b'Skipping line 538495: expected 12 fields, saw 13\n'
# b'Skipping line 765901: expected 12 fields, saw 56\nSkipping line 773310: expected 12 fields, saw 43\n'
# b'Skipping line 805899: expected 12 fields, saw 13\nSkipping line 868492: expected 12 fields, saw 21\nSkipping line 871801: expected 12 fields, saw 16\n'
# b'Skipping line 903099: expected 12 fields, saw 13\nSkipping line 903150: expected 12 fields, saw 13\nSkipping line 903155: expected 12 fields, saw 13\nSkipping line 926112: expected 12 fields, saw 13\n'
# b'Skipping line 952511: expected 12 fields, saw 14\nSkipping line 954085: expected 12 fields, saw 13\nSkipping line 956504: expected 12 fields, saw 40\nSkipping line 981135: expected 12 fields, saw 13\nSkipping line 983460: expected 12 fields, saw 16\nSkipping line 985000: expected 12 fields, saw 15\nSkipping line 986754: expected 12 fields, saw 13\nSkipping line 986828: expected 12 fields, saw 13\n'
# b'Skipping line 1334533: expected 12 fields, saw 13\nSkipping line 1337066: expected 12 fields, saw 16\nSkipping line 1343528: expected 12 fields, saw 13\nSkipping line 1351606: expected 12 fields, saw 14\n'
# b'Skipping line 1376142: expected 12 fields, saw 16\nSkipping line 1376408: expected 12 fields, saw 15\nSkipping line 1389213: expected 12 fields, saw 59\nSkipping line 1401635: expected 12 fields, saw 23\n'
# b'Skipping line 1762082: expected 12 fields, saw 13\nSkipping line 1763155: expected 12 fields, saw 16\n'
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.drop(["url", "video_url", "source_name", "author_name"], axis=1)
df = df.dropna()
df = df.drop_duplicates()

# %%
def ner(sent):
    sent = word_tokenize(sent)
    tagged = pos_tag(sent)
    ne = nltk.ne_chunk(tagged)
    return ne

# %%
for text in df['result.tsv'][:10]:
    entities = ner(text)
    print(entities)
# Out:
# (S
#   (PERSON Сборная/JJ)
#   (ORGANIZATION Турции/NNP)
#   продолжает/NNP
#   свою/NNP
#   дорогу/NNP
#   на/NNP
#   Чемпионат/NNP
#   (PERSON Европы/NNP)
#   и/NNP
#   перед/NNP
#   очередными/NNP
#   матчами/NNP
#   отбора/NNP
#   решила/NNP
#   размяться/NNP
#   в/NNP
#   товарищеском/NNP
#   матче/NNP
#   ./.
#   Узбекистан/VB
#   не/JJ
#   преследует/NNP
#   больших/NNP
#   турнирных/NNP
#   задач/NNP
#   и/NNP
#   просто/NNP
#   сыграет/NNP
#   два/NNP
#   товарищеских/NNP
#   матча/NNP
#   за/NNP
#   неделю/NNP
#   ./.
#   Турки/VB
#   стали/JJ
#   самой/NNP
#   слабой/NNP
#   командой/NNP
#   группы/NNP
#   В2/NNP
#   Лиги/NNP
#   наций/NNP
#   ,/,
#   проиграв/NNP
#   три/NNP
#   игры/NNP
#   из/NNP
#   четырех/NNP
#   ./.
#   Тогда/VB
#   команда/JJ
#   финишировала/NNP
#   с/NNP
#   тремя/NNP
#   очками/NNP
#   ,/,
#   семью/NNP
#   пропущенными/NNP
#   и/NNP
#   четырьмя/NNP
#   забитыми/NNP
#   голами/NNP
#   ./.
#   В/VB
#   следующий/JJ
#   раз/NNP
#   (PERSON Турция/NNP)
#   уже/NNP
#   будет/NNP
#   играть/NNP
#   на/NNP
#   один/NNP
#   дивизион/NNP
#   ниже/NNP
#   ,/,
#   а/NNP
#   пока/NNP
#   старается/NNP
#   выйти/NNP
#   на/NNP
#   Чемпионат/NNP
#   (PERSON Европы/NNP)
#   через/NNP
#   отборочный/NNP
#   этап/NNP
#   ./.
#   Там/VB
#   удалось/JJ
#   добыть/NNP
#   максимальное/NNP
#   количество/NNP
#   очков/NNP
#   после/NNP
#   двух/NNP
#   матчей/NNP
#   и/NNP
#   команда/NNP
#   делит/NNP
#   первое/NNP
#   место/NNP
#   с/NNP
#   Францией/NNP
#   ./.
#   Тем/VB
#   не/JJ
#   менее/NNP
#   ,/,
#   важные/NNP
#   испытания/NNP
#   только/NNP
#   предстоят/NNP
#   –/NNP
#   уже/NNP
#   на/NNP
#   этой/NNP
#   неделе/NNP
#   команду/NNP
#   ожидают/NNP
#   встречи/NNP
#   с/NNP
#   Чемпионом/NNP
#   Мира/NNP
#   ,/,
#   а/NNP
#   затем/NNP
#   выезд/NNP
#   в/NNP
#   суровую/NNP
#   Исландию/NNP
#   ./.
#   Хоть/VB
#   встреча/JJ
#   с/NNP
#   Францией/NNP
#   и/NNP
#   не/NNP
#   предполагает/NNP
#   ничего/NNP
#   хорошего/NNP
#   ,/,
#   турки/NNP
#   наверняка/NNP
#   постараются/NNP
#   выжать/NNP
#   максимум/NNP
#   из/NNP
#   этого/NNP
#   матча/NNP
#   ./.
#   Поэтому/VB
#   с/JJ
#   трудом/NNP
#   верится/NNP
#   ,/,
#   что/NNP
#   с/NNP
#   Узбекистаном/NNP
#   выйдет/NNP
#   играть/NNP
#   безапелляционно/NNP
#   основной/NNP
#   состав/NNP
#   и/NNP
#   будет/NNP
#   биться/NNP
#   за/NNP
#   каждый/NNP
#   участок/NNP
#   поля/NNP
#   ./.
#   В/VB
#   голове/JJ
#   будут/NNP
#   мысли/NNP
#   о/NNP
#   том/NNP
#   ,/,
#   что/NNP
#   нужно/NNP
#   поберечь/NNP
#   силы/NNP
#   ./.
#   Узбекистан/VB
#   –/JJ
#   сильная/NNP
#   по/NNP
#   меркам/NNP
#   Азии/NNP
#   сборная/NNP
#   ,/,
#   которая/NNP
#   стабильно/NNP
#   выходит/NNP
#   в/NNP
#   плей-офф/JJ
#   континентального/NNP
#   чемпионата/NNP
#   ./.
#   В/VB
#   этом/JJ
#   году/NNP
#   вновь/NNP
#   удалось/NNP
#   пробраться/NNP
#   в/VBD
#   1/8/CD
#   через/NNP
#   второе/NNP
#   место/NNP
#   в/NNP
#   группе/NNP
#   ,/,
#   где/NNP
#   с/NNP
#   минимальным/NNP
#   счетом/NNP
#   выиграла/NNP
#   сборная/NNP
#   Австралии/NNP
#   ./.
#   Руководство/VB
#   ставит/JJ
#   большие/NNP
#   цели/NNP
#   ,/,
#   к/NNP
#   которым/NNP
#   ведет/NNP
#   команду/NNP
#   Эктор/NNP
#   Купер/NNP
#   ,/,
#   тренировавший/NNP
#   (PERSON Египет/NNP)
#   на/NNP
#   Чемпионате/NNP
#   мира/NNP
#   ./.
#   К/VB
#   товарищеским/JJ
#   матчам/NNP
#   команда/NNP
#   относится/NNP
#   серьезно/NNP
#   ./.
#   Иногда/VB
#   она/JJ
#   выбирает/NNP
#   статусные/NNP
#   сборные/NNP
#   уровня/NNP
#   сборной/NNP
#   Уругвая/NNP
#   ,/,
#   с/NNP
#   которой/NNP
#   провела/NNP
#   свой/NNP
#   предпоследний/NNP
#   матч/NNP
#   ./.
#   Иногда/VB
#   тестирует/JJ
#   себя/NNP
#   на/NNP
#   фоне/NNP
#   конкурентов/NNP
#   по/NNP
#   Азии/NNP
#   ,/,
#   как/NNP
#   это/NNP
#   было/NNP
#   в/NNP
#   Марте/NNP
#   против/NNP
#   Китая/NNP
#   –/NNP
#   тогда/NNP
#   сборная/NNP
#   Узбекистана/NNP
#   одержала/NNP
#   минимальную/NNP
#   победу/NNP
#   в/NNP
#   гостях/NNP
#   ./.
#   У/VB
#   меня/JJ
#   четкое/NNP
#   ощущение/NNP
#   ,/,
#   что/NNP
#   букмекеры/NNP
#   переоценивают/NNP
#   превосходство/NNP
#   сборной/NNP
#   Турции/NNP
#   ,/,
#   а/NNP
#   в/NNP
#   частности/NNP
#   –/NNP
#   мотивацию/NNP
#   команды/NNP
#   на/NNP
#   этот/NNP
#   матч/NNP
#   ./.
#   Узбекистан/VB
#   очень/JJ
#   хорошо/NNP
#   организован/NNP
#   и/NNP
#   приучен/NNP
#   к/NNP
#   матчам/NNP
#   высокого/NNP
#   уровня/NNP
#   ./.
#   При/VB
#   этом/JJ
#   (PERSON Эктора/NNP Купера/NNP)
#   не/NNP
#   сдерживает/NNP
#   плотный/NNP
#   календарь/NNP
#   –/NNP
#   напротив/NNP
#   тренер/NNP
#   предпочитает/NNP
#   наигрывать/NNP
#   костяк/NNP
#   в/NNP
#   товарищеских/NNP
#   матчах/NNP
#   и/NNP
#   подбирать/NNP
#   оптимальные/NNP
#   сочетания/NNP
#   ./.
#   Будет/VB
#   большим/JJ
#   сюрпризом/NNP
#   ,/,
#   если/NNP
#   турки/NNP
#   сыграют/NNP
#   в/NNP
#   основном/NNP
#   варианте/NNP
#   и/NNP
#   будут/NNP
#   биться/NNP
#   за/NNP
#   победу/NNP
#   ./.
#   Поэтому/VB
#   я/JJ
#   с/NNP
#   подстраховкой/NNP
#   возьму/NNP
#   Ф2/NNP
#   (/(
#   -1,5/NNP
#   )/)
#   за/VBD
#   1,65/CD
#   в/NNP
#   этой/NNP
#   игре/NNP
#   ./.)
# (S
#   (PERSON Двадцать/JJ)
#   девятого/NNP
#   числа/NNP
#   состоится/NNP
#   один/NNP
#   весьма/NNP
#   престижный/NNP
#   матч/NNP
#   в/NNP
#   рамках/NNP
#   четвертьфинальной/NNP
#   стадии/NNP
#   Кубка/NNP
#   Америки/NNP
#   ./.
#   Столь/VB
#   глубоко/JJ
#   позволила/NNP
#   себе/NNP
#   Колумбия/NNP
#   ,/,
#   которой/NNP
#   будет/NNP
#   противостоять/NNP
#   Чили/NNP
#   ./.
#   Мероприятие/VB
#   начнется/JJ
#   в/NNP
#   два/NNP
#   часа/NNP
#   ночи/NNP
#   по/NNP
#   московскому/NNP
#   времени/NNP
#   на/NNP
#   стадионе/NNP
#   «/NNP
#   Коринтианс/NNP
#   »/NNP
#   ,/,
#   что/NNP
#   расположен/NNP
#   в/NNP
#   Сан-Паулу/NNP
#   ./.
#   Плавными/VB
#   шагами/JJ
#   можно/NNP
#   переходить/NNP
#   к/NNP
#   оценке/NNP
#   букмекерской/NNP
#   линии/NNP
#   ./.
#   Достойное/VB
#   событие/JJ
#   двух/NNP
#   достойных/NNP
#   коллективов/NNP
#   ./.
#   Даже/VB
#   как-то/JJ
#   обидно/NN
#   ,/,
#   что/NNP
#   придется/NNP
#   попрощаться/NNP
#   с/NNP
#   одной/NNP
#   из/NNP
#   крепких/NNP
#   команд/NNP
#   на/NNP
#   четвертьфинальной/NNP
#   стадии/NNP
#   ./.
#   Говорить/VB
#   в/JJ
#   нашем/NNP
#   случае/NNP
#   о/NNP
#   букмекерах/NNP
#   –/NNP
#   все/NNP
#   равно/NNP
#   ,/,
#   что/NNP
#   рассуждать/NNP
#   о/NNP
#   женщинах/NNP
#   ./.
#   Разговор/VB
#   может/JJ
#   затянуться/NNP
#   на/NNP
#   многие/NNP
#   часы/NNP
#   ./.
#   (PERSON Просто/NN)
#   обозначим/NN
#   ,/,
#   что/NNP
#   сильные/NNP
#   мира/NNP
#   сего/NNP
#   не/NNP
#   выделяют/NNP
#   очевидного/NNP
#   фаворита/NNP
#   ,/,
#   с/NNP
#   чем/NNP
#   гам/NNP
#   остается/NNP
#   лишь/NNP
#   согласиться/NNP
#   ./.
#   Теперь/VB
#   можно/JJ
#   толковать/NNP
#   более/NNP
#   подробно/NNP
#   ./.
#   «/VB
#   (PERSON Кофейщики/JJ)
#   »/NNP
#   отлично/NNP
#   провели/NNP
#   групповую/NNP
#   стадию/NNP
#   турнира/NNP
#   ./.
#   Не/VB
#   будем/JJ
#   сильно/NNP
#   углубляться/NNP
#   в/NNP
#   метафизические/NNP
#   процессы/NNP
#   ./.
#   Достаточно/VB
#   просто/JJ
#   поддать/NNP
#   анализу/NNP
#   самый/NNP
#   свежий/NNP
#   матч/NNP
#   ,/,
#   что/NNP
#   случился/NNP
#   двадцать/NNP
#   третьего/NNP
#   числа/NNP
#   ./.
#   В/VB
#   тот/JJ
#   день/NNP
#   дружина/NNP
#   (PERSON Карлуша/NNP Кейруша/NNP)
#   встретилась/NNP
#   против/NNP
#   Парагвая/NNP
#   ./.
#   Не/VB
#   самое/JJ
#   простое/NNP
#   сражение/NNP
#   ,/,
#   но/NNP
#   ребята/NNP
#   умудрились/NNP
#   забить/NNP
#   гол/NNP
#   на/NNP
#   тридцать/NNP
#   первой/NNP
#   минуте/NNP
#   ./.
#   Как/NN
#   оказалось/NN
#   ,/,
#   то/NNP
#   был/NNP
#   единственный/NNP
#   результативный/NNP
#   удар/NNP
#   ./.
#   В/VB
#   группе/JJ
#   В/NNP
#   также/NNP
#   участвовала/NNP
#   Аргентина/NNP
#   ,/,
#   но/NNP
#   «/NNP
#   кофейщики/NNP
#   »/NNP
#   сумели/NNP
#   ее/NNP
#   обыграть/NNP
#   в/NNP
#   стартовом/NNP
#   туре/NNP
#   со/NNP
#   счетом/VBD
#   0:2/CD
#   ./.
#   После/VB
#   такой/JJ
#   заявки/NNP
#   стало/NNP
#   понятно/NNP
#   ,/,
#   кто/NNP
#   возглавит/NNP
#   турнирную/NNP
#   таблицу/NNP
#   ./.
#   За/VB
#   три/JJ
#   тура/NNP
#   коллектив/NNP
#   собрал/NNP
#   девять/NNP
#   баллов/NNP
#   ./.
#   У/VB
#   ближайшего/JJ
#   преследователя/NNP
#   оказалось/NNP
#   на/NNP
#   целых/NNP
#   пять/NNP
#   пунктов/NNP
#   меньше/NNP
#   ./.
#   Несмотря/VB
#   на/JJ
#   то/NNP
#   ,/,
#   что/NNP
#   атаке/NNP
#   у/NNP
#   дружины/NNP
#   есть/NNP
#   знаковые/NNP
#   исполнители/NNP
#   ,/,
#   команда/NNP
#   отлично/NNP
#   держит/NNP
#   оборону/NNP
#   ./.
#   Ноль/VB
#   пропущенных/JJ
#   голов/NNP
#   лишь/NNP
#   подтверждают/NNP
#   наши/NNP
#   слова/NNP
#   ./.
#   «/VB
#   (PERSON Красные/JJ)
#   »/NNP
#   неудачно/NNP
#   закончили/NNP
#   групповую/NNP
#   часть/NNP
#   турнира/NNP
#   ./.
#   Однако/VB
#   винить/JJ
#   их/NNP
#   в/NNP
#   этом/NNP
#   сложно/NNP
#   ./.
#   Двадцать/VB
#   пятого/JJ
#   числа/NNP
#   дружина/NNP
#   встретилась/NNP
#   против/NNP
#   сборной/NNP
#   Уругвая/NNP
#   ./.
#   Тут/VB
#   автоматически/JJ
#   шансы/NNP
#   сходят/NNP
#   к/NNP
#   нулю/NNP
#   ./.
#   До/VB
#   восемьдесят/JJ
#   второй/NNP
#   минуты/NNP
#   «/NNP
#   Ла/NNP
#   Роха/NNP
#   »/NNP
#   даже/NNP
#   умудрялась/NNP
#   сдерживать/NNP
#   атакующие/NNP
#   потуги/NNP
#   врага/NNP
#   ,/,
#   но/NNP
#   в/NNP
#   указанное/NNP
#   роковое/NNP
#   время/NNP
#   отметился/NNP
#   (PERSON Эдинсон/NNP Кавани/NNP)
#   –/NNP
#   закономерное/NNP
#   поражение/NNP
#   со/NNP
#   счетом/VBD
#   0:1/CD
#   ./.
#   После/VB
#   трех/JJ
#   туров/NNP
#   групповой/NNP
#   стадии/NNP
#   команда/NNP
#   собрала/NNP
#   шесть/NNP
#   баллов/NNP
#   ./.
#   Подобный/VB
#   результат/JJ
#   равняется/NNP
#   второй/NNP
#   позиции/NNP
#   в/NNP
#   турнирной/NNP
#   таблице/NNP
#   ./.
#   Уругвайского/VB
#   врага/JJ
#   так/NNP
#   и/NNP
#   не/NNP
#   удалось/NNP
#   настичь/NNP
#   ./.
#   Перед/VB
#   стартом/JJ
#   (PERSON Копы/NNP)
#   многие/NNP
#   ставили/NNP
#   на/NNP
#   то/NNP
#   ,/,
#   что/NNP
#   чилийцам/NNP
#   даже/NNP
#   не/NNP
#   удастся/NNP
#   выйти/NNP
#   из/NNP
#   группы/NNP
#   ./.
#   Поколение/VB
#   фактически/JJ
#   исчерпало/NNP
#   себя/NNP
#   ,/,
#   а/NNP
#   женщины/NNP
#   банально/NNP
#   не/NNP
#   рождают/NNP
#   достойную/NNP
#   замену/NNP
#   ./.
#   Однако/VB
#   выйти/JJ
#   из/NNP
#   группы/NNP
#   у/NNP
#   парней/NNP
#   получилось/NNP
#   ./.
#   В/VB
#   последних/JJ
#   очных/NNP
#   встречах/NNP
#   команды/NNP
#   играли/NNP
#   максимально/NNP
#   нерезультативно/NNP
#   ./.
#   Оба/VB
#   тренера/JJ
#   обладают/NNP
#   опытными/NNP
#   защитными/NNP
#   редутами/NNP
#   ./.
#   Можно/VB
#   не/JJ
#   сомневаться/NNP
#   ,/,
#   что/NNP
#   и/NNP
#   на/NNP
#   сей/NNP
#   раз/NNP
#   результативность/NNP
#   будет/NNP
#   хромать/NNP
#   на/NNP
#   обе/NNP
#   ноги/NNP
#   ./.)
# (S
#   АЗ/JJ
#   (PERSON Алкмар/NNP В/NNP)
#   первом/NNP
#   матче/NNP
#   голландский/NNP
#   клуб/NNP
#   создал/NNP
#   уйму/NNP
#   моментов/NNP
#   ,/,
#   чтобы/NNP
#   отличиться/NNP
#   неоднократно/NNP
#   ./.
#   К/VB
#   сожалению/JJ
#   ни/NNP
#   один/NNP
#   из/NNP
#   шансов/NNP
#   не/NNP
#   завершился/NNP
#   взятием/NNP
#   ворот/NNP
#   ./.
#   Было/VB
#   нанесено/JJ
#   18/CD
#   ударов/NN
#   ,/,
#   а/NNP
#   в/NNP
#   створ/NNP
#   из/NNP
#   них/NNP
#   пришлось/NNP
#   только/NNP
#   семь/NNP
#   ./.
#   Два/VB
#   самых/JJ
#   острых/NNP
#   момента/NNP
#   были/NNP
#   созданы/NNP
#   на/VBD
#   19/CD
#   и/JJ
#   82/CD
#   минутах/NN
#   ./.
#   В/CC
#   обоих/JJ
#   случаях/NNP
#   великолепные/NNP
#   сейвы/NNP
#   совершил/NNP
#   голкипер/NNP
#   ``/``
#   Мариуполя/NN
#   ''/''
#   (PERSON Рустам/NN Худжамов/NNP)
#   ./.
#   Игроки/VB
#   атаки/JJ
#   (PERSON Идрисси/NNP)
#   и/NNP
#   Боаду/NNP
#   не/NNP
#   использовали/NNP
#   эти/NNP
#   отличные/NNP
#   моменты/NNP
#   ./.
#   Несмотря/VB
#   на/JJ
#   не/NNP
#   лучшую/NNP
#   реализацию/NNP
#   в/NNP
#   том/NNP
#   матче/NNP
#   ,/,
#   стоит/NNP
#   отметить/NNP
#   ,/,
#   что/NNP
#   оборона/NNP
#   ``/``
#   АЗ/NN
#   ''/''
#   отработала/NN
#   идеально/NNP
#   ./.
#   Она/VB
#   действует/JJ
#   очень/NNP
#   уверенно/NNP
#   ,/,
#   не/NNP
#   пропуская/NNP
#   уже/NNP
#   пять/NNP
#   встреч/NNP
#   кряду/NNP
#   ./.
#   ``/``
#   Мариуполь/JJ
#   ''/''
#   (PERSON Команда/NN понимает/NNP)
#   ,/,
#   что/NNP
#   в/NNP
#   выездном/NNP
#   матче/NNP
#   ей/NNP
#   придется/NNP
#   несладко/NNP
#   ./.
#   На/VB
#   своем/JJ
#   поле/NNP
#   ``/``
#   Мариуполь/NN
#   ''/''
#   очень/CC
#   хотел/NNP
#   забить/NNP
#   ./.
#   В/VB
#   глазах/JJ
#   футболистов/NNP
#   была/NNP
#   видна/NNP
#   искра/NNP
#   и/NNP
#   неистовое/NNP
#   рвение/NNP
#   ./.
#   Даже/VB
#   вратарь/JJ
#   команды/NNP
#   прибежал/NNP
#   из/NNP
#   своих/NNP
#   ворот/NNP
#   на/NNP
#   последний/NNP
#   угловой/NNP
#   ,/,
#   добрался/NNP
#   там/NNP
#   до/NNP
#   мяча/NNP
#   ,/,
#   но/NNP
#   пробил/NNP
#   намного/NNP
#   выше/NNP
#   ворот/NNP
#   ./.
#   Ну/VB
#   а/JJ
#   что/NNP
#   еще/NNP
#   остается/NNP
#   делать/NNP
#   ,/,
#   если/NNP
#   у/NNP
#   полевых/NNP
#   футболистов/NNP
#   игра/NNP
#   не/NNP
#   задалась/NNP
#   ./.
#   Единственный/VB
#   голевой/JJ
#   момент/NNP
#   создал/NNP
#   Игорь/NNP
#   Тищенко/NNP
#   ,/,
#   выйдя/NNP
#   один/NNP
#   на/NNP
#   один/NNP
#   с/NNP
#   вратарем/NNP
#   ,/,
#   но/NNP
#   не/NNP
#   сумел/NNP
#   переиграть/NNP
#   его/NNP
#   ./.
#   Прогноз/VB
#   и/JJ
#   ставки/NNP
#   В/NNP
#   домашнем/NNP
#   матче/NNP
#   ``/``
#   АЗ/FW
#   Алкмар/NN
#   ''/''
#   должен/CC
#   компенсировать/NNP
#   все/NNP
#   упущенные/NNP
#   моменты/NNP
#   в/NNP
#   Одессе/NNP
#   ./.
#   (PERSON Допускаю/NN)
#   ,/,
#   что/NNP
#   в/NNP
#   воротах/NNP
#   ``/``
#   Мариуполя/NN
#   ''/''
#   окажется/CC
#   не/NNP
#   один/NNP
#   мяч/NNP
#   ,/,
#   а/NNP
#   где-то/NNP
#   два/NNP
#   или/NNP
#   три/NNP
#   ,/,
#   причем/NNP
#   хозяева/NNP
#   смогут/NNP
#   отличиться/NNP
#   в/NNP
#   каждом/NNP
#   из/NNP
#   таймов/NNP
#   ./.)
# (S
#   «/JJ
#   (PERSON Сачхере/NNP)
#   »/NNP
#   —/NNP
#   «/NNP
#   (PERSON Абердин/NNP)
#   »/NNP
#   И/NNP
#   тот/NNP
#   ,/,
#   и/NNP
#   другой/NNP
#   клуб/NNP
#   одержали/NNP
#   победы/NNP
#   в/NNP
#   обеих/NNP
#   встречах/NNP
#   первого/NNP
#   отборочного/NNP
#   раунда/NNP
#   ./.
#   Удивительно/NN
#   ,/,
#   что/NNP
#   все/NNP
#   эти/NNP
#   четыре/NNP
#   матча/NNP
#   завершились/NNP
#   с/NNP
#   одинаковым/NNP
#   счетом/VBD
#   2:1/CD
#   ./.
#   То/NN
#   ,/,
#   что/NNP
#   в/NNP
#   двух/NNP
#   матчах/NNP
#   и/NNP
#   те/NNP
#   ,/,
#   и/NNP
#   другие/NNP
#   забили/NNP
#   по/NNP
#   четыре/NNP
#   гола/NNP
#   -/:
#   показатель/NN
#   неплохой/NN
#   ,/,
#   но/NNP
#   вот/NNP
#   то/NNP
#   ,/,
#   что/NNP
#   ни/NNP
#   в/NNP
#   одной/NNP
#   из/NNP
#   встреч/NNP
#   не/NNP
#   удалось/NNP
#   сохранить/NNP
#   свои/NNP
#   ворота/NNP
#   не/NNP
#   распечатанными/NNP
#   -/:
#   крайне/NN
#   тревожный/JJ
#   сигнал/NNP
#   ./.
#   Не/NN
#   исключено/NN
#   ,/,
#   что/NNP
#   и/NNP
#   в/NNP
#   предстоящем/NNP
#   поединке/NNP
#   нас/NNP
#   может/NNP
#   ждать/NNP
#   обмен/NNP
#   голами/NNP
#   ./.
#   На/VB
#   бумаге/JJ
#   фаворитом/NNP
#   считается/NNP
#   шотландский/NNP
#   клуб/NNP
#   ./.
#   Я/VB
#   с/JJ
#   этим/NNP
#   абсолютно/NNP
#   согласен/NNP
#   ./.
#   На/VB
#   мой/JJ
#   взгляд/NNP
#   ,/,
#   уровень/NNP
#   шотландского/NNP
#   футбола/NNP
#   выше/NNP
#   грузинского/NNP
#   ./.
#   Все-таки/JJ
#   в/JJ
#   групповых/NN
#   стадиях/NNP
#   еврокубков/NNP
#   мы/NNP
#   довольно/NNP
#   часто/NNP
#   встречаем/NNP
#   именно/NNP
#   представителей/NNP
#   Шотландии/NNP
#   ,/,
#   но/NNP
#   никак/NNP
#   не/NNP
#   Грузии/NNP
#   ./.
#   (PERSON Считаю/NN)
#   ,/,
#   что/VBP
#   ``/``
#   Абердину/JJ
#   ''/''
#   под/NN
#   силу/NNP
#   выиграть/NNP
#   в/NNP
#   первом/NNP
#   матче/NNP
#   ,/,
#   предрешив/NNP
#   тем/NNP
#   самым/NNP
#   выход/NNP
#   в/NNP
#   следующую/NNP
#   стадию/NNP
#   ./.
#   «/VB
#   (PERSON Флора/JJ)
#   »/NNP
#   —/NNP
#   «/NNP
#   Айнтрахт/NNP
#   »/NNP
#   В/NNP
#   этом/NNP
#   противостоянии/NNP
#   пропасть/NNP
#   в/NNP
#   уровне/NNP
#   между/NNP
#   командами/NNP
#   -/:
#   видна/NN
#   налицо/NN
#   ./.
#   ``/``
#   Айнтрахт/JJ
#   ''/''
#   блестяще/NN
#   выступил/NNP
#   в/NNP
#   прошлом/NNP
#   розыгрыше/NNP
#   Лиги/NNP
#   Европы/NNP
#   ,/,
#   дойдя/NNP
#   до/NNP
#   стадии/NNP
#   полуфинала/NNP
#   ./.
#   Да/VB
#   и/JJ
#   в/NNP
#   противостоянии/NNP
#   с/NNP
#   ``/``
#   Челси/NN
#   ''/''
#   команда/CC
#   смотрелась/NNP
#   более/NNP
#   чем/NNP
#   достойно/NNP
#   ,/,
#   уступив/NNP
#   лишь/NNP
#   в/NNP
#   серии/NNP
#   послематчевых/NNP
#   пенальти/NNP
#   (/(
#   3:4/CD
#   )/)
#   ./.
#   Такое/JJ
#   досадное/JJ
#   поражение/NN
#   ни/NNP
#   может/NNP
#   не/NNP
#   мотивировать/NNP
#   немецкий/NNP
#   клуб/NNP
#   выступить/NNP
#   в/NNP
#   этом/NNP
#   розыгрыше/NNP
#   еще/NNP
#   более/NNP
#   успешно/NNP
#   ./.
#   По/VB
#   эстонским/JJ
#   меркам/NNP
#   ``/``
#   Флора/NN
#   ''/''
#   -/:
#   очень/NN
#   боеспособный/NN
#   коллектив/NNP
#   ,/,
#   занимающий/NNP
#   в/NNP
#   чемпионате/NNP
#   на/NNP
#   данный/NNP
#   момент/NNP
#   первую/NNP
#   строчку/NNP
#   ./.
#   Но/VB
#   в/JJ
#   матче/NNP
#   с/NNP
#   немецкой/NNP
#   командой/NNP
#   ей/NNP
#   будет/NNP
#   очень/NNP
#   непросто/NNP
#   ./.
#   (PERSON Допускаю/NN)
#   ,/,
#   что/NNP
#   в/NNP
#   первом/NNP
#   же/NNP
#   матче/NNP
#   будут/NNP
#   сняты/NNP
#   все/NNP
#   вопросы/NNP
#   ./.
#   (PERSON Думаю/NN)
#   ,/,
#   что/VBP
#   ``/``
#   Айнтрахт/JJ
#   ''/''
#   забьет/NN
#   как/NNP
#   минимум/NNP
#   три/NNP
#   гола/NNP
#   ,/,
#   а/NNP
#   возможно/NNP
#   и/NNP
#   более/NNP
#   ./.
#   «/VB
#   (ORGANIZATION АЗ/JJ Алкмар/NNP)
#   »/NNP
#   —/NNP
#   «/NNP
#   (PERSON Хеккен/NNP)
#   »/NNP
#   В/NNP
#   рамках/NNP
#   подготовки/NNP
#   к/NNP
#   старту/NNP
#   выступления/NNP
#   во/NNP
#   втором/NNP
#   отборочном/NNP
#   раунде/NNP
#   Лиги/NNP
#   (PERSON Европы/NNP)
#   голландский/NNP
#   клуб/NNP
#   провел/NNP
#   ряд/NNP
#   товарищеских/NNP
#   встреч/NNP
#   ./.
#   Результаты/VB
#   этих/JJ
#   матчей/NNP
#   оставили/NNP
#   невнятное/NNP
#   впечатление/NNP
#   о/NNP
#   состоянии/NNP
#   ``/``
#   Алкмара/NN
#   ''/''
#   на/CC
#   данный/NNP
#   момент/NNP
#   ./.
#   (PERSON Тех/NN)
#   ,/,
#   кого/NNP
#   должны/NNP
#   были/NNP
#   ,/,
#   обыграли/NNP
#   ,/,
#   но/NNP
#   проиграли/NNP
#   тем/NNP
#   ,/,
#   кто/NNP
#   уровнем/NNP
#   значительно/NNP
#   выше/NNP
#   ./.
#   В/VB
#   чемпионате/JJ
#   (PERSON Швеции/NNP)
#   сейчас/NNP
#   сезон/NNP
#   в/NNP
#   самом/NNP
#   разгаре/NNP
#   ./.
#   ``/``
#   Хеккен/JJ
#   ''/''
#   (PERSON Команда/NN)
#   располагается/NNP
#   на/NNP
#   четвертой/NNP
#   строчке/NNP
#   всего/NNP
#   в/NNP
#   шести/NNP
#   очках/NNP
#   от/NNP
#   лидера/NNP
#   ,/,
#   так/NNP
#   что/NNP
#   можно/NNP
#   говорить/NNP
#   ,/,
#   что/NNP
#   команда/NNP
#   претендует/NNP
#   на/NNP
#   чемпионство/NNP
#   ./.
#   Совмещать/VB
#   национальное/JJ
#   первенство/NNP
#   и/NNP
#   выступление/NNP
#   в/NNP
#   еврокубках/NNP
#   никому/NNP
#   не/NNP
#   просто/NNP
#   ,/,
#   но/NNP
#   предполагаю/NNP
#   ,/,
#   что/NNP
#   к/NNP
#   этому/NNP
#   футболисты/NNP
#   готовы/NNP
#   ./.
#   Преимущество/VB
#   гостей/JJ
#   в/NNP
#   том/NNP
#   ,/,
#   что/NNP
#   они/NNP
#   активно/NNP
#   вовлечены/NNP
#   в/NNP
#   официальные/NNP
#   поединки/NNP
#   ,/,
#   ``/``
#   Алкмару/NN
#   ''/''
#   же/CC
#   это/NNP
#   только/NNP
#   предстоит/NNP
#   сделать/NNP
#   ./.
#   Но/VB
#   на/JJ
#   мой/NNP
#   взгляд/NNP
#   класс/NNP
#   хозяев/NNP
#   повыше/NNP
#   и/NNP
#   они/NNP
#   способны/NNP
#   победить/NNP
#   на/NNP
#   своем/NNP
#   поле/NNP
#   ./.)
# (S
#   Я/JJ
#   предполагаю/NNP
#   ничью/NNP
#   в/NNP
#   этом/NNP
#   матче/NNP
#   с/NNP
#   забитыми/NNP
#   мячами/NNP
#   ,/,
#   но/NNP
#   низовую/NNP
#   -/:
#   менее/NN
#   2,5/CD
#   гола/NN
#   ,/,
#   то/NNP
#   есть/VBZ
#   1:1/CD
#   ./.
#   (PERSON Думаю/NN)
#   ,/,
#   что/VBP
#   ``/``
#   Валенсия/JJ
#   ''/''
#   ``/``
#   Арсеналу/FW
#   ''/''
#   два/NN
#   матча/NNP
#   подряд/NNP
#   не/NNP
#   проиграет/NNP
#   ./.
#   Но/VB
#   в/JJ
#   этой/NNP
#   паре/NNP
#   все/NNP
#   было/NNP
#   предопределено/NNP
#   в/NNP
#   первом/NNP
#   поединке/NNP
#   ./.
#   Поэтому/SYM
#   -/:
#   1:1/CD
#   ./.
#   ``/``
#   Арсенал/JJ
#   ''/''
#   откроет/NN
#   счет/NNP
#   ,/,
#   ``/``
#   Валенсия/NN
#   ''/''
#   его/NN
#   сравняет/NNP
#   ./.
#   И/VB
#   в/JJ
#   итоге/NNP
#   ничья/NNP
#   ./.
#   Читайте/VB
#   о/JJ
#   коэффициентах/NNP
#   и/NNP
#   ставках/NNP
#   на/NNP
#   матч/NNP
#   «/NNP
#   Валенсия/NNP
#   »/NNP
#   —/NNP
#   «/NNP
#   (PERSON Арсенал/NNP)
#   »/NNP
#   от/NNP
#   букмекеров/NNP
#   России/NNP
#   ./.
#   «/VB
#   (PERSON Лига/JJ Ставок/NNP)
#   »/NNP
#   —/VBD
#   Гран-при/JJ
#   :/:
#   абсолютно/JJ
#   лучший/NNP
#   букмекер/NNP
#   BR/NNP
#   Awards/NNP
#   2019/CD
#   ./.)
# (S
#   (PERSON Июль/JJ)
#   подходит/NNP
#   к/NNP
#   концу/NNP
#   ./.
#   Скоро/VB
#   мадридское/JJ
#   дерби/NNP
#   —/NNP
#   «/NNP
#   Реал/NNP
#   »/NNP
#   против/NNP
#   «/NNP
#   Атлетико/NNP
#   »/NNP
#   ./.
#   Хоть/VB
#   этот/JJ
#   матч/NNP
#   носит/NNP
#   неофициальный/NNP
#   характер/NNP
#   ,/,
#   данная/NNP
#   вывеска/NNP
#   смотрится/NNP
#   очень/NNP
#   эффектно/NNP
#   ./.
#   Команды/VB
#   за/JJ
#   всю/NNP
#   историю/NNP
#   противостояний/NNP
#   ни/NNP
#   разу/NNP
#   не/NNP
#   встречались/NNP
#   в/NNP
#   товарищеских/NNP
#   поединках/NNP
#   ./.
#   Одержит/VB
#   ли/JJ
#   первую/NNP
#   победу/NNP
#   «/NNP
#   королевский/NNP
#   »/NNP
#   клуб/NNP
#   в/NNP
#   Международном/NNP
#   кубке/NNP
#   чемпионов/NNP
#   (/(
#   далее/NNP
#   МКЧ/NNP
#   )/)
#   ?/.
#   Главный/JJ
#   тренер/NN
#   пробует/NNP
#   разные/NNP
#   схемы/NNP
#   и/NNP
#   расстановки/NNP
#   на/NNP
#   игру/NNP
#   ./.
#   В/VB
#   первом/JJ
#   матче/NNP
#   против/NNP
#   «/NNP
#   (PERSON Баварии/NNP)
#   »/NNP
#   можно/NNP
#   было/NNP
#   увидеть/NNP
#   4-3-2-1/JJ
#   (/(
#   или/JJ
#   4-3-3/NN
#   )/)
#   ,/,
#   то/JJ
#   есть/NNP
#   с/NNP
#   одним/NNP
#   центральным/NNP
#   нападающим/NNP
#   (/(
#   в/NNP
#   первом/NNP
#   тайме/NNP
#   —/NNP
#   Бензема/NNP
#   ,/,
#   во/NNP
#   втором/NNP
#   —/NNP
#   Йович/NNP
#   )/)
#   ./.
#   В/JJ
#   целом/JJ
#   у/NN
#   команды/NNP
#   мало/NNP
#   что/NNP
#   получалось/NNP
#   в/NNP
#   атаке/NNP
#   ,/,
#   так/NNP
#   как/NNP
#   было/NNP
#   видно/NNP
#   ,/,
#   что/NNP
#   нет/NNP
#   сыгранности/NNP
#   ./.
#   Карим/VB
#   очень/JJ
#   часто/NNP
#   нереализовывал/NNP
#   моменты/NN
#   :/:
#   в/JJ
#   простых/NNP
#   ситуациях/NNP
#   не/NNP
#   попадал/NNP
#   по/NNP
#   мячу/NNP
#   ./.
#   Левандовский/VB
#   во/JJ
#   втором/NNP
#   тайме/NNP
#   показал/NNP
#   как/NNP
#   нужно/NNP
#   забивать/NNP
#   гол/NNP
#   ./.
#   По/VB
#   голевым/JJ
#   моментам/NNP
#   ,/,
#   которые/NNP
#   заканчивались/NNP
#   ударами/NNP
#   ,/,
#   2-7/JJ
#   (/(
#   !/.
#   )/)
#   в/VBP
#   пользу/JJ
#   «/NNP
#   красных/NNP
#   »/NNP
#   ./.
#   Во/VB
#   втором/JJ
#   поединке/NNP
#   против/NNP
#   «/NNP
#   Арсенала/NNP
#   »/NNP
#   с/NNP
#   первых/NNP
#   минут/NNP
#   расстановка/NNP
#   4-4-2/JJ
#   ,/,
#   где/JJ
#   (PERSON Йович/NNP)
#   и/NNP
#   (PERSON Бензема/NNP)
#   —/NNP
#   два/NNP
#   форварда/NNP
#   ./.
#   (PERSON Однако/NN)
#   ,/,
#   мы/NNP
#   не/NNP
#   смогли/NNP
#   посмотреть/NNP
#   что/NNP
#   задумал/NNP
#   Зидан/NNP
#   на/NNP
#   игру/NNP
#   ,/,
#   потому/NNP
#   как/NNP
#   уже/NNP
#   на/VBD
#   9/CD
#   минуте/NNP
#   был/NNP
#   удален/NNP
#   защитник/NNP
#   Начо/NNP
#   ./.
#   Команда/VB
#   перешла/JJ
#   на/NNP
#   4-4-1/CD
#   ,/,
#   хотя/NNP
#   длилось/NNP
#   это/NNP
#   недолго/NNP
#   ./.
#   Удаление/VB
#   у/JJ
#   «/NNP
#   канониров/NNP
#   »/NNP
#   и/NNP
#   составы/NNP
#   уравнялись/NNP
#   ./.
#   Минус/CC
#   2/CD
#   футболиста/JJ
#   и/NNP
#   на/NNP
#   футбольном/NNP
#   поле/NNP
#   появилось/NNP
#   больше/NNP
#   пространства/NNP
#   для/NNP
#   футболистов/NNP
#   ./.
#   Статистика/VB
#   голевых/JJ
#   моментов/NN
#   :/:
#   5-6/JJ
#   (/(
#   !/.
#   )/)
#   в/VBP
#   пользу/JJ
#   «/NNP
#   красно-белых/JJ
#   »/NNP
#   ./.
#   В/VB
#   двух/JJ
#   матчах/NNP
#   «/NNP
#   белые/NNP
#   »/NNP
#   часто/NNP
#   били/NNP
#   по/NNP
#   воротам/NNP
#   при/NNP
#   первой/NNP
#   же/NNP
#   возможности/NNP
#   ./.
#   (PERSON Видимо/NN)
#   ,/,
#   это/NNP
#   установка/NNP
#   тренера/NNP
#   ./.
#   В/VB
#   отличии/JJ
#   от/NNP
#   оппонента/NNP
#   ,/,
#   «/NNP
#   матрасники/NNP
#   »/NNP
#   в/NNP
#   МКЧ/NNP
#   провели/VBD
#   1/CD
#   игру/NNP
#   против/NNP
#   «/NNP
#   Гвадалахара/NNP
#   »/NNP
#   ./.
#   По/VB
#   игре/JJ
#   «/NNP
#   Атлетико/NNP
#   »/NNP
#   не/NNP
#   выглядил/NNP
#   фаворитом/NNP
#   в/NNP
#   данной/NNP
#   встрече/NNP
#   ,/,
#   хоть/NNP
#   и/NNP
#   не/NNP
#   пропустил/NNP
#   мяч/NNP
#   ./.
#   Практически/VB
#   ноль/JJ
#   голевых/NNP
#   моментов/NNP
#   ./.
#   Счет/CC
#   0:0/CD
#   —/JJ
#   отражает/NNP
#   всю/NNP
#   суть/NNP
#   матча/NNP
#   ./.
#   (PERSON Были/NN)
#   полумоменты/NN
#   ,/,
#   как/NNP
#   в/NNP
#   одной/NNP
#   ,/,
#   так/NNP
#   и/NNP
#   в/NNP
#   другой/NNP
#   команде/NNP
#   ,/,
#   но/NNP
#   никому/NNP
#   не/NNP
#   удалось/NNP
#   забить/NNP
#   гол/NNP
#   ./.
#   (PERSON Стоит/NN)
#   заметить/NN
#   ,/,
#   что/NNP
#   это/NNP
#   был/NNP
#   первый/NNP
#   поединок/NNP
#   подопечных/NNP
#   (PERSON Симионе/NNP)
#   в/NNP
#   МКЧ/NNP
#   ./.
#   Еще/VB
#   один/JJ
#   немаловажный/JJ
#   нюанс/NN
#   :/:
#   футболисты/JJ
#   «/NNP
#   Атлетико/NNP
#   »/NNP
#   играли/NNP
#   ,/,
#   в/NNP
#   основном/NNP
#   ,/,
#   первым/NNP
#   номером/NNP
#   ./.
#   (PERSON Снова/NN)
#   ,/,
#   как/NNP
#   и/NNP
#   в/NNP
#   матче/NNP
#   «/NNP
#   Реал/NNP
#   »/NNP
#   —/NNP
#   «/NNP
#   (PERSON Арсенал/NNP)
#   »/NNP
#   ,/,
#   было/NNP
#   удаление/NNP
#   ./.
#   Льоренте/VB
#   получил/JJ
#   прямую/NNP
#   красную/NNP
#   карточку/NNP
#   и/NNP
#   мы/NNP
#   не/NNP
#   смогли/NNP
#   полностью/NNP
#   понять/NNP
#   план/NNP
#   на/NNP
#   игру/NNP
#   главного/NNP
#   тренера/NNP
#   ./.
#   Клубы/VB
#   встречались/JJ
#   197/CD
#   раз/NN
#   !/.
#   102/CD
#   победы/JJ
#   у/NNP
#   «/NNP
#   сливочных/NNP
#   »/NNP
#   и/NNP
#   всего/NNP
#   лишь/VBD
#   50/CD
#   у/JJ
#   АТМ/NN
#   ./.
#   Разница/CC
#   забитых/JJ
#   и/NNP
#   пропущенных/NNP
#   мячей/NN
#   :/:
#   339-257/JJ
#   (/(
#   в/JJ
#   среднем/NNP
#   за/NNP
#   матч/NN
#   :/:
#   1.72-1.3/JJ
#   )/)
#   в/FW
#   пользу/FW
#   «/FW
#   Реала/FW
#   »/FW
#   ./.
#   Обратите/FW
#   внимание/NN
#   ,/,
#   за/NNP
#   последние/VBZ
#   12/CD
#   игр/NN
#   в/VBD
#   8/CD
#   встречах/NNP
#   «/NNP
#   Атлетико/NNP
#   »/NNP
#   удалось/NNP
#   забить/NNP
#   в/NNP
#   основное/NNP
#   время/VBD
#   1/CD
#   или/JJ
#   2/CD
#   гола/NN
#   ./.
#   Красная/CC
#   звезда/JJ
#   возле/NNP
#   поединка/NNP
#   —/NNP
#   основное/NNP
#   время/NNP
#   игры/NNP
#   закончилось/NNP
#   со/NNP
#   счетом/VBD
#   2:2/CD
#   ./.
#   Обе/VB
#   команды/JJ
#   не/NNP
#   показывают/NNP
#   тот/NNP
#   уровень/NNP
#   футбола/NNP
#   ,/,
#   который/NNP
#   ждут/NNP
#   болельщики/NNP
#   и/NNP
#   тренерский/NNP
#   персонал/NNP
#   ./.
#   Матч/VB
#   не/JJ
#   имеет/NNP
#   никакого/NNP
#   стимула/NNP
#   для/NNP
#   клубов/NNP
#   ./.
#   Тренера/VB
#   могут/JJ
#   с/NNP
#   первых/NNP
#   минут/NNP
#   выставить/NNP
#   те/NNP
#   составы/NNP
#   ,/,
#   которые/NNP
#   захотят/NNP
#   ./.
#   Предположим/NN
#   ,/,
#   что/NNP
#   в/NNP
#   первом/NNP
#   тайме/NNP
#   выйдет/NNP
#   на/NNP
#   острие/NNP
#   атаки/NNP
#   не/NNP
#   француз/NNP
#   ,/,
#   а/NNP
#   Йович/NNP
#   ,/,
#   в/NNP
#   воротах/NNP
#   —/NNP
#   украинец/NNP
#   Лунин/NNP
#   ./.
#   Уж/VB
#   пора/JJ
#   им/NNP
#   доверить/NNP
#   место/NNP
#   в/NNP
#   основе/NNP
#   ./.
#   В/VB
#   последние/JJ
#   игры/NNP
#   «/NNP
#   королевский/NNP
#   »/NNP
#   клуб/NNP
#   много/NNP
#   пропускает/NNP
#   ./.
#   У/VB
#   (ORGANIZATION АТМ/JJ)
#   это/NNP
#   будет/NNP
#   вторая/NNP
#   игра/NNP
#   и/NNP
#   против/NNP
#   принципиального/NNP
#   соперника/NNP
#   ./.
#   Не/VB
#   стоит/JJ
#   ожидать/NNP
#   сухой/NNP
#   матч/NNP
#   ./.
#   Оба/VB
#   коллектива/JJ
#   вполне/NNP
#   смогут/NNP
#   забить/NNP
#   1-2/JJ
#   гола/NNP
#   ./.
#   Вторая/VB
#   команда/JJ
#   выглядит/NNP
#   чуть/NNP
#   более/NNP
#   лучше/NNP
#   ,/,
#   так/NNP
#   как/NNP
#   у/NNP
#   первой/NNP
#   побольше/NNP
#   проблем/NN
#   :/:
#   новые/NN
#   игроки/NN
#   ,/,
#   несыгранность/NNP
#   ,/,
#   трудности/NNP
#   в/NNP
#   оборонительной/NNP
#   игре/NNP
#   и/NNP
#   многое/NNP
#   другое/NNP
#   ./.)
# (S
#   «/JJ
#   (PERSON Ахмат/NNP)
#   »/NNP
#   ,/,
#   который/NNP
#   доставил/NNP
#   много/NNP
#   проблем/NNP
#   командам/NNP
#   из/NNP
#   ТОП-3/JJ
#   в/NNP
#   прошлом/NNP
#   сезоне/NNP
#   ,/,
#   принимает/NNP
#   на/NNP
#   домашнем/NNP
#   стадионе/NNP
#   футбольный/NNP
#   клуб/NNP
#   «/NNP
#   Краснодар/NNP
#   »/NNP
#   уже/NNP
#   в/NNP
#   первом/NNP
#   туре/NNP
#   чемпионата/NNP
#   России/NNP
#   ./.
#   Букмекеры/VB
#   отдают/JJ
#   предпочтение/NNP
#   гостям/NNP
#   ,/,
#   где/NNP
#   их/NNP
#   вероятность/NNP
#   победы/NNP
#   оценивается/NNP
#   в/VBD
#   46/CD
#   %/NN
#   ./.
#   Почему/CC
#   же/JJ
#   «/JJ
#   черно-зеленым/JJ
#   »/NN
#   стоит/NNP
#   опасаться/NNP
#   команды/NNP
#   из/NNP
#   города/NNP
#   Грозный/NNP
#   ?/.
#   Вполне/NN
#   да/NN
#   ./.
#   Два/CC
#   сезона/JJ
#   подряд/NNP
#   команда/NNP
#   находится/NNP
#   в/NNP
#   средине/NNP
#   таблицы/NNP
#   РПЛ/NNP
#   ./.
#   (PERSON Главное/NN)
#   ,/,
#   «/NNP
#   Ахмат/NNP
#   »/NNP
#   остается/NNP
#   неудобным/NNP
#   соперником/NNP
#   абсолютно/NNP
#   для/NNP
#   всех/NNP
#   клубов/NNP
#   ./.
#   Не/VB
#   зря/JJ
#   их/NNP
#   прозвище/NNP
#   —/NNP
#   «/NNP
#   зверьки/NNP
#   »/NNP
#   ./.
#   2017/2018/CD
#   ./.
#   На/VB
#   изображении/JJ
#   вы/NNP
#   видите/NNP
#   результаты/NNP
#   домашних/NNP
#   игр/NNP
#   ./.
#   Позапрошлый/VB
#   сезон/JJ
#   —/$
#   9/CD
#   позиция/NNP
#   ./.
#   Клуб/VB
#   только/JJ
#   вышел/NNP
#   в/NNP
#   Премьер-лигу/JJ
#   и/NNP
#   крепко/NNP
#   закрепился/NNP
#   в/NNP
#   средине/NNP
#   таблицы/NNP
#   ./.
#   При/VB
#   чем/JJ
#   каждому/NNP
#   сопернику/NNP
#   из/NNP
#   верхней/NNP
#   10-ки/JJ
#   «/NNP
#   зелено-белые/JJ
#   »/NNP
#   смогли/NNP
#   забить/NNP
#   гол/NNP
#   (/(
#   исключение/NNP
#   —/NNP
#   «/NNP
#   ЦСКА/NNP
#   »/NNP
#   )/)
#   ./.
#   2018/2019/CD
#   ./.
#   Практически/VB
#   та/JJ
#   же/NNP
#   картина/NNP
#   —/VBD
#   8/CD
#   место/NNP
#   и/NNP
#   результативная/NNP
#   борьба/NNP
#   с/NNP
#   грандами/NNP
#   Премьер-лиги/NNP
#   ./.
#   Обратите/VB
#   внимание/JJ
#   на/NNP
#   выделенные/NNP
#   результаты/NNP
#   красным/NNP
#   цветом/NNP
#   ./.
#   «/VB
#   (PERSON Ахмат/JJ)
#   »/NNP
#   на/NNP
#   домашнем/NNP
#   стадионе/NNP
#   отличился/VBD
#   7/CD
#   раз/NNP
#   из/$
#   10/CD
#   (/(
#   2017/2018/CD
#   )/)
#   ,/,
#   8/CD
#   из/NN
#   10/CD
#   (/(
#   2018/2019/CD
#   )/)
#   ./.
#   Берем/JJ
#   во/JJ
#   внимание/NN
#   первые/NNP
#   десять/NNP
#   команд/NNP
#   из/NNP
#   турнирной/NNP
#   таблицы/NNP
#   ./.
#   Подопечные/VB
#   (PERSON Рахимова/JJ)
#   провели/NNP
#   шесть/NNP
#   контрольных/NNP
#   матчей/NN
#   :/:
#   «/JJ
#   (PERSON Хольштейн/NNP Киель/NNP)
#   »/NNP
#   (/(
#   (ORGANIZATION Германия/NNP)
#   )/)
#   1:0/CD
#   ,/,
#   «/NNP
#   Запрешич/NNP
#   »/NNP
#   (/(
#   (ORGANIZATION Хорватия/NNP)
#   )/)
#   1:1/CD
#   ,/,
#   «/NNP
#   Штурм/NNP
#   »/NNP
#   (/(
#   (ORGANIZATION Австрия/NNP)
#   )/)
#   3:0/CD
#   ,/,
#   «/NNP
#   Дунайська/NNP
#   (PERSON Стреда/NNP)
#   »/NNP
#   (/(
#   (ORGANIZATION Словакия/NNP)
#   )/)
#   5:1/CD
#   ,/,
#   «/NNP
#   Види/NNP
#   »/NNP
#   (/(
#   (ORGANIZATION Венгрия/NNP)
#   )/)
#   2:1/CD
#   ,/,
#   «/NNP
#   (PERSON Марибор/NNP)
#   »/NNP
#   (/(
#   (ORGANIZATION Словения/NNP)
#   )/)
#   3:2/CD
#   ./.
#   В/NN
#   итоге/NN
#   ,/,
#   5/CD
#   побед/NN
#   и/VBD
#   1/CD
#   ничья/NN
#   ./.
#   Команда/CC
#   из/JJ
#   города/NNP
#   (PERSON Грозный/NNP)
#   провела/NNP
#   хорошую/NNP
#   трансферную/NNP
#   политику/NNP
#   ./.
#   Особенно/VB
#   стоит/JJ
#   выделить/NNP
#   приобретение/NNP
#   футболиста/NNP
#   Глушакова/NNP
#   ,/,
#   но/NNP
#   его/NNP
#   участие/NNP
#   в/NNP
#   матче/NNP
#   остается/NNP
#   под/NNP
#   вопросом/NNP
#   ./.
#   Начнем/VB
#   с/JJ
#   хорошего/NN
#   :/:
#   «/JJ
#   (PERSON Краснодар/NNP)
#   »/NNP
#   —/NNP
#   победитель/NNP
#   турнира/NNP
#   «/NNP
#   Матч/NNP
#   Премьер/NNP
#   »/NN
#   2019/CD
#   ./.
#   В/VB
#   остальных/JJ
#   товарищеских/NNP
#   играх/NNP
#   —/VBD
#   2/CD
#   поражения/NNP
#   и/VBD
#   1/CD
#   ничья/NN
#   ./.
#   Таким/JJ
#   образом/NN
#   ,/,
#   за/VBZ
#   6/CD
#   поединков/NN
#   разница/NNP
#   забитых/NNP
#   и/NNP
#   пропущенных/NNP
#   мячей/NN
#   :/:
#   8-7/JJ
#   ./.
#   (/(
#   В/JJ
#   4/CD
#   матчах/JJ
#   из/JJ
#   6-ти/JJ
#   соперники/NN
#   забили/NNP
#   гол/NNP
#   )/)
#   Что/VBP
#   касается/JJ
#   чемпионата/NNP
#   ,/,
#   клуб/NNP
#   ,/,
#   в/NNP
#   основном/NNP
#   ,/,
#   занимает/VBD
#   4/CD
#   место/NN
#   ./.
#   Лишь/CC
#   в/JJ
#   прошлом/NNP
#   сезоне/NNP
#   —/NNP
#   третья/NNP
#   позиция/NNP
#   спустя/NNP
#   пять/NNP
#   лет/NNP
#   ./.
#   В/VB
#   двух/JJ
#   последних/NNP
#   сезонах/NNP
#   клуб/NNP
#   в/NNP
#   первых/NNP
#   турах/NNP
#   пропускал/NNP
#   гол/NNP
#   ,/,
#   где/NNP
#   дважды/NNP
#   встретил/NNP
#   «/NNP
#   (PERSON Рубина/NNP)
#   »/NNP
#   (/(
#   в/NNP
#   прошлом/NNP
#   чемпионате/NNP
#   проиграл/NNP
#   со/NNP
#   счетом/NNP
#   1:2/CD
#   ,/,
#   в/NNP
#   позапрошлом/NNP
#   выиграл/NNP
#   —/NNP
#   2:1/CD
#   )/)
#   ./.
#   На/JJ
#   выезде/JJ
#   команда/NN
#   демонстрирует/NNP
#   неплохие/NNP
#   результаты/NNP
#   ,/,
#   но/NNP
#   пропускает/NNP
#   достаточно/NNP
#   часто/NNP
#   ./.
#   2018/2019/CD
#   ./.
#   (/(
#   (ORGANIZATION Учитываем/JJ)
#   определенные/NNP
#   первенства/NNP
#   )/)
#   ./.
#   «/JJ
#   Краснодар/JJ
#   »/NN
#   пропустил/NNP
#   мяч/NNP
#   в/NNP
#   десяти/NNP
#   играх/NNP
#   (/(
#   всего/$
#   15/CD
#   подинков/NN
#   )/)
#   ./.
#   2017/2018/CD
#   ./.
#   Аналогичная/VB
#   ситуация/JJ
#   —/$
#   10/CD
#   из/JJ
#   15/CD
#   ./.
#   Газинский/VB
#   и/JJ
#   (ORGANIZATION Клаэссон/NNP)
#   вряд/NNP
#   ли/NNP
#   смогут/NNP
#   принять/NNP
#   участие/NNP
#   в/NNP
#   сегодняшнем/NNP
#   поединке/NNP
#   ./.
#   Команды/VB
#   встречаются/JJ
#   не/NNP
#   в/NNP
#   первый/NNP
#   раз/NNP
#   ./.
#   Обратите/VB
#   внимание/JJ
#   на/NNP
#   пять/NNP
#   последних/NNP
#   поединков/NN
#   :/:
#   в/JJ
#   каждом/NNP
#   из/NNP
#   них/NNP
#   «/NNP
#   Ахмат/NNP
#   »/NNP
#   отличился/NNP
#   забитым/NNP
#   мячом/NNP
#   ./.
#   (PERSON Более/NN)
#   того/NN
#   ,/,
#   начиная/NNP
#   с/NNP
#   конца/NNP
#   2016/CD
#   года/NNP
#   «/NNP
#   Краснодар/NNP
#   »/NNP
#   пропускает/NNP
#   гол/NNP
#   (/(
#   1-2/JJ
#   )/)
#   на/FW
#   выезде/FW
#   ./.
#   В/CC
#   трех/JJ
#   последних/NNP
#   играх/NNP
#   «/NNP
#   зверьки/NNP
#   »/NNP
#   забивали/NNP
#   мяч/NNP
#   в/NNP
#   ворота/NNP
#   оппонента/NNP
#   ./.
#   Команда/VB
#   «/JJ
#   (PERSON Ахмат/NNP)
#   »/NNP
#   вполне/NNP
#   способна/NNP
#   распечатать/NNP
#   ворота/NNP
#   «/NNP
#   Краснодара/NNP
#   »/NNP
#   ./.
#   Коэффициент/VB
#   на/JJ
#   событие/NNP
#   «/NNP
#   Ахмат/NNP
#   забьет/NNP
#   гол/NN
#   :/:
#   да/JJ
#   »/NNP
#   около/NNP
#   1.54/CD
#   ./.
#   (PERSON Однако/NN)
#   ,/,
#   есть/NNP
#   практически/NNP
#   аналогичная/NNP
#   ставка/NNP
#   первой/NNP
#   ,/,
#   но/NNP
#   она/NNP
#   находится/NNP
#   только/NNP
#   на/NNP
#   двух/NNP
#   букмекерских/NNP
#   конторах/NNP
#   ./.
#   На/VB
#   (ORGANIZATION Париматче/JJ)
#   можно/JJ
#   увидеть/NN
#   :/:
#   «/JJ
#   (PERSON Ахмат/NNP)
#   забьет/NNP
#   1/CD
#   или/VBD
#   2/CD
#   гола/NN
#   :/:
#   да/JJ
#   »/NN
#   ./.)
# (S
#   (PERSON Никто/JJ)
#   толком/NNP
#   не/NNP
#   представляет/NNP
#   ,/,
#   в/NNP
#   каких/NNP
#   составах/NNP
#   будут/NNP
#   играть/NNP
#   команды/NNP
#   ./.
#   Предстоящий/NN
#   матч/SYM
#   -/:
#   подготовительный/NN
#   период/JJ
#   и/NNP
#   начало/NNP
#   серии/NNP
#   выставочных/NNP
#   товарищеских/NNP
#   матчей/NNP
#   ./.
#   Хотя/VB
#   вывеска/JJ
#   очень/NNP
#   громкая/NNP
#   -/:
#   «/NN
#   (PERSON Арсенал/JJ)
#   »/NNP
#   —/NNP
#   «/NNP
#   (PERSON Бавария/NNP)
#   »/NNP
#   ,/,
#   мне/NNP
#   кажется/NNP
#   ,/,
#   что/NNP
#   неопределенность/NNP
#   сохраняется/NNP
#   очень/NNP
#   высокая/NNP
#   ./.
#   На/VB
#   мой/JJ
#   взгляд/NNP
#   ,/,
#   ``/``
#   Бавария/NN
#   ''/''
#   является/NN
#   командой/NNP
#   ,/,
#   которая/NNP
#   крепко/NNP
#   стоит/NNP
#   на/NNP
#   ногах/NNP
#   и/NNP
#   знает/NNP
#   ,/,
#   чего/NNP
#   она/NNP
#   хочет/NNP
#   ./.
#   В/VB
#   то/JJ
#   время/NNP
#   как/NNP
#   ``/``
#   Арсенал/NN
#   ''/''
#   в/CC
#   подготовительный/NNP
#   период/NNP
#   только/NNP
#   пытается/NNP
#   найти/NNP
#   себя/NNP
#   ./.
#   Мой/NN
#   прогноз/SYM
#   -/:
#   ``/``
#   Бавария/NN
#   ''/''
#   выиграет/CC
#   со/NNP
#   счетом/NNP
#   2:0/CD
#   ,/,
#   забив/NNP
#   по/NNP
#   голу/NNP
#   в/NNP
#   каждом/NNP
#   из/NNP
#   таймов/NNP
#   ,/,
#   ``/``
#   Арсенал/NN
#   ''/''
#   не/CC
#   забьет/NNP
#   и/NNP
#   игра/NNP
#   окажется/NNP
#   низовой/NNP
#   ./.)
# (S
#   (PERSON Матч/JJ)
#   вроде/NNP
#   бы/NNP
#   товарищеский/NNP
#   ,/,
#   но/NNP
#   -/:
#   это/NN
#   и/NN
#   репутация/NNP
#   ,/,
#   и/NNP
#   борьба/NNP
#   с/NNP
#   конкурентами/NNP
#   за/NNP
#   место/NNP
#   в/NNP
#   составе/NNP
#   ,/,
#   ну/NNP
#   и/NNP
#   прочие/NNP
#   приятные/NNP
#   бонусы/NNP
#   ,/,
#   такие/NNP
#   заманчивые/NNP
#   мотивационные/NNP
#   истории/NNP
#   ./.
#   В/VB
#   этой/JJ
#   игре/NNP
#   ,/,
#   мне/NNP
#   кажется/NNP
#   ,/,
#   надо/NNP
#   ставить/NNP
#   на/NNP
#   ``/``
#   Барселону/NN
#   ''/''
#   ,/,
#   которая/NNP
#   более/NNP
#   сыгранная/NNP
#   ,/,
#   понятная/NNP
#   ,/,
#   не/NNP
#   опускающаяся/NNP
#   в/NNP
#   классе/NNP
#   ниже/NNP
#   каких-то/JJ
#   своих/NNP
#   предельных/NNP
#   отметок/NNP
#   ./.
#   Я/VB
#   попробую/JJ
#   предположить/NNP
#   ,/,
#   что/NNP
#   ``/``
#   Барселона/NN
#   ''/''
#   выиграет/CC
#   этот/NNP
#   матч/NNP
#   всухую/NNP
#   со/NNP
#   счетом/NNP
#   2:0/CD
#   ,/,
#   забив/NNP
#   по/NNP
#   голу/NNP
#   в/NNP
#   каждом/NNP
#   из/NNP
#   таймов/NNP
#   ,/,
#   тем/NNP
#   самым/NNP
#   игра/NNP
#   окажется/NNP
#   низовой/NNP
#   ./.
#   ``/``
#   Челси/JJ
#   ''/''
#   не/NN
#   забьет/NNP
#   ,/,
#   так/NNP
#   как/NNP
#   будет/NNP
#   искать/NNP
#   свою/NNP
#   новую/NNP
#   игру/NNP
#   и/NNP
#   своего/NNP
#   нового/NNP
#   лидера/NNP
#   ./.)
# (S
#   (PERSON Беларусь/JJ)
#   –/NNP
#   Эстония/NN
#   :/:
#   прогноз/JJ
#   и/NNP
#   ставка/NNP
#   на/NNP
#   матч/VBD
#   10/CD
#   октября/NN
#   2019/CD
#   года/NN
#   ./.
#   Матч/JJ
#   7-го/JJ
#   тура/NN
#   квалификации/NNP
#   на/NNP
#   Чемпионат/NNP
#   Европы-2020/JJ
#   начнется/NNP
#   в/NNP
#   19:00/CD
#   на/NNP
#   стадионе/NNP
#   «/NNP
#   (PERSON Динамо/NNP)
#   »/NNP
#   ./.
#   Статистика/VB
#   личных/JJ
#   встреч/NNP
#   ,/,
#   обзор/NNP
#   матча/NNP
#   ,/,
#   составы/NNP
#   команд/NNP
#   и/NNP
#   коэффициенты/NNP
#   букмекеров/NNP
#   ./.
#   «/VB
#   (PERSON Беларусь/JJ)
#   »/NNP
#   (PERSON Сборная/NNP Беларуси/NNP)
#   занимает/NNP
#   4-ое/JJ
#   место/NNP
#   в/NNP
#   группе/NNP
#   «/NNP
#   С/NNP
#   »/NNP
#   с/VBD
#   3/CD
#   очками/NNP
#   после/VBD
#   5/CD
#   сыгранных/JJ
#   туров/NN
#   ./.
#   Разница/CC
#   мячей/JJ
#   составляет/JJ
#   3-10/JJ
#   ./.
#   Единственную/JJ
#   свою/JJ
#   победу/NN
#   белорусы/NNP
#   одержали/NNP
#   в/NNP
#   (PERSON Таллине/NNP)
#   в/NNP
#   матче/NNP
#   со/NNP
#   сборной/NNP
#   Эстонии/VBD
#   6/CD
#   сентября/NNP
#   со/NNP
#   счетом/NNP
#   1-2/JJ
#   ./.
#   Это/JJ
#   был/JJ
#   первый/NN
#   матч/NNP
#   сборной/NNP
#   Беларуси/NNP
#   под/NNP
#   руководством/NNP
#   (PERSON Михаил/NNP Мархеля/NNP)
#   ,/,
#   и/NNP
#   дебют/NNP
#   нового/NNP
#   главного/NNP
#   тренера/NNP
#   удался/NNP
#   ./.
#   Белорусы/VB
#   выглядели/JJ
#   лучше/NNP
#   эстонцев/NNP
#   ,/,
#   создали/NNP
#   достаточное/NNP
#   количество/NNP
#   голевых/NNP
#   моментов/NNP
#   ,/,
#   но/NNP
#   победный/NNP
#   мяч/NNP
#   забили/NNP
#   лишь/NNP
#   на/NNP
#   92-ой/CD
#   минуте.Ближайшие/NNP
#   (ORGANIZATION прогнозыГермания/NNP)
#   -/:
#   (ORGANIZATION АргентинаТурнир/NN)
#   :/:
#   Товарищеский/JJ
#   матч/NNP
#   (PERSON Начало/NNP)
#   матча/VBD
#   09/CD
#   Октября/JJ
#   21:45/CD
#   МСК/JJ
#   Ставка/NN
#   :/:
#   Обе/JJ
#   забьют/JJ
#   Коэффициент/NN
#   :/:
#   1,66/CD
#   1000/CD
#   руб/NN
#   за/NNP
#   регистрацию/NNP
#   (PERSON Сделать/NNP)
#   реальную/NNP
#   ставку/NNP
#   (PERSON Австрия/NNP)
#   -/:
#   ИзраильТурнир/NN
#   :/:
#   Евро-2020/JJ
#   (PERSON Начало/NNP)
#   матча/NNP
#   10/CD
#   Октября/VBD
#   21:45/CD
#   МСК/JJ
#   Ставка/NN
#   :/:
#   ТБ/JJ
#   2,5/CD
#   Коэффициент/NN
#   :/:
#   1,85/CD
#   10000/CD
#   руб/NN
#   за/NNP
#   регистрацию/NNP
#   (PERSON Сделать/NNP)
#   реальную/NNP
#   ставку/NNP
#   После/NNP
#   победного/NNP
#   матча/NNP
#   в/NNP
#   (PERSON Эстонии/NNP)
#   сборная/NNP
#   Беларуси/NNP
#   сыграла/NNP
#   товарищеский/NNP
#   матч/NNP
#   с/NNP
#   (PERSON Уэльсом/NNP)
#   в/NNP
#   гостях/NNP
#   и/NNP
#   проиграла/NNP
#   со/NNP
#   счетом/NNP
#   1-0/JJ
#   ./.
#   В/JJ
#   этой/JJ
#   игре/NN
#   (PERSON Мархель/NNP)
#   выпустил/NNP
#   в/NNP
#   стартовом/NNP
#   составе/NNP
#   ,/,
#   преимущественно/NNP
#   ,/,
#   тех/NNP
#   футболистов/NNP
#   ,/,
#   которые/NNP
#   не/NNP
#   играли/NNP
#   в/NNP
#   Таллине/NNP
#   ./.
#   Результат/VB
#   в/JJ
#   товарищеском/NNP
#   матче/NNP
#   был/NNP
#   не/NNP
#   столь/NNP
#   важен/NNP
#   ,/,
#   и/NNP
#   главный/NNP
#   тренер/NNP
#   сборной/NNP
#   использовал/NNP
#   возможность/NNP
#   просмотреть/NNP
#   максимально/NNP
#   возможное/NNP
#   количество/NNP
#   футболистов/NNP
#   в/NNP
#   деле/NNP
#   ./.
#   Даже/VB
#   сейчас/JJ
#   (PERSON Мархель/NNP)
#   не/NNP
#   скрывает/NNP
#   ,/,
#   что/NNP
#   не/NNP
#   до/NNP
#   конца/NNP
#   определился/NNP
#   с/NNP
#   теми/NNP
#   игроками/NNP
#   ,/,
#   на/NNP
#   которых/NNP
#   рассчитывает/NNP
#   в/NNP
#   будущем/NNP
#   ./.
#   После/VB
#   продолжительного/JJ
#   перерыва/NNP
#   сборная/NNP
#   Беларуси/NNP
#   сыграет/NNP
#   в/NNP
#   Минске/NNP
#   ./.
#   На/VB
#   обновленном/JJ
#   стадионе/NNP
#   «/NNP
#   (PERSON Динамо/NNP)
#   »/NNP
#   сборная/NNP
#   Беларуси/NNP
#   еще/NNP
#   не/NNP
#   проигрывала/NN
#   :/:
#   две/JJ
#   победы/NNP
#   и/NNP
#   ничья/NNP
#   ./.
#   (PERSON Более/NN)
#   того/NN
#   ,/,
#   в/NNP
#   этих/NNP
#   играх/NNP
#   белорусы/NNP
#   ни/NNP
#   разу/NNP
#   не/NNP
#   пропустили./NNP
#   «/NNP
#   (PERSON Эстония/NNP)
#   »/NNP
#   (PERSON Сборная/NNP Эстонии/NNP)
#   расположилась/NNP
#   на/NNP
#   последнем/NNP
#   месте/NNP
#   в/NNP
#   группе/NNP
#   «/NNP
#   С/NNP
#   »/NNP
#   с/VBD
#   0/CD
#   очков/NN
#   ./.
#   Команда/CC
#   под/JJ
#   руководством/NNP
#   (PERSON Карела/NNP Воолайда/NNP)
#   пропустила/NNP
#   в/VBD
#   5/CD
#   матчах/JJ
#   18/CD
#   мячей/NN
#   ,/,
#   а/NNP
#   забить/NNP
#   смогла/NNP
#   только/NNP
#   дважды/NNP
#   ./.
#   В/VB
#   домашнем/JJ
#   матче/NNP
#   со/NNP
#   сборной/NNP
#   Беларуси/NNP
#   эстонцы/NNP
#   не/NNP
#   показали/NNP
#   хорошей/NNP
#   игры/NNP
#   и/NNP
#   заслуженно/NNP
#   проиграли/NNP
#   ./.
#   После/VB
#   поражения/JJ
#   от/NNP
#   белорусов/NNP
#   последовал/NNP
#   домашний/NNP
#   проигрыш/NNP
#   сборной/NNP
#   Нидерландов/NNP
#   со/NNP
#   счетом/NNP
#   0-4/NN
#   ./.
#   В/JJ
#   этом/JJ
#   матче/NN
#   у/NNP
#   эстонцев/NNP
#   тем/NNP
#   более/NNP
#   не/NNP
#   было/NNP
#   никаких/NNP
#   шансов/NNP
#   ./.
#   Гости/VB
#   забили/JJ
#   четыре/NNP
#   и/NNP
#   могли/NNP
#   забивать/NNP
#   еще/NNP
#   несколько/NNP
#   голов/NNP
#   ./.
#   Матч/VB
#   в/JJ
#   (PERSON Минске/NNP)
#   для/NNP
#   сборной/NNP
#   (PERSON Эстонии/NNP)
#   остается/NNP
#   последней/NNP
#   более-менее/JJ
#   реальной/NNP
#   возможностью/NNP
#   завоевать/NNP
#   очки/NNP
#   в/NNP
#   этой/NNP
#   квалификации/NNP
#   ./.
#   «/VB
#   Я/JJ
#   хотел/NNP
#   взять/NNP
#   три/NNP
#   очка/NNP
#   в/NNP
#   Таллинне/NNP
#   ,/,
#   и/NNP
#   сейчас/NNP
#   у/NNP
#   меня/NNP
#   такая/NNP
#   же/NNP
#   цель/NNP
#   ./.
#   (PERSON Игра/NN)
#   покажет/NN
#   ,/,
#   чей/NNP
#   план/NNP
#   сработает/NNP
#   лучше/NNP
#   ./.
#   Не/NN
#   знаю/NN
#   ,/,
#   останусь/NNP
#   ли/NNP
#   доволен/NNP
#   ничьей/NNP
#   –/NNP
#   это/NNP
#   будет/NNP
#   зависеть/NNP
#   от/NNP
#   хода/NNP
#   встречи/NNP
#   ./.
#   Не/NN
#   думаю/NN
#   ,/,
#   что/NNP
#   белорусы/NNP
#   выступят/NNP
#   хуже/NNP
#   ,/,
#   чем/NNP
#   в/NNP
#   Эстонии/NNP
#   ,/,
#   –/NNP
#   скорее/NNP
#   они/NNP
#   должны/NNP
#   прибавить/NNP
#   ./.
#   Но/VB
#   и/JJ
#   мы/NNP
#   тоже/NNP
#   »/NNP
#   ,/,
#   –/NNP
#   сказал/NNP
#   (PERSON Воолайд/NNP)
#   перед/NNP
#   матчем/NNP
#   в/NNP
#   Минске./NNP
#   «/NNP
#   Беларусь/NNP
#   »/NNP
#   —/NNP
#   «/NNP
#   Эстония/NNP
#   »/NN
#   :/:
#   травмы/JJ
#   и/NNP
#   дисквалификации/NNP
#   В/NNP
#   сборную/NNP
#   Беларуси/NNP
#   не/NNP
#   приехали/NNP
#   из-за/JJ
#   травм/NNP
#   Нехайчик/NNP
#   и/NNP
#   Гордейчук/NNP
#   ./.
#   Лучший/VB
#   бомбардир/JJ
#   чемпионата/NNP
#   Беларуси/NNP
#   Илья/NNP
#   (PERSON Шкурин/NNP)
#   сыграет/NNP
#   за/NNP
#   «/NNP
#   молодежку/NNP
#   »/NNP
#   ./.
#   В/VB
#   сборной/JJ
#   (PERSON Эстонии/NNP)
#   нет/NNP
#   (PERSON Клавана/NNP)
#   из/NNP
#   «/NNP
#   (PERSON Кальяри/NNP)
#   »/NNP
#   и/NNP
#   Дмитриев/NNP
#   из/NNP
#   «/NNP
#   Окжетпеса/NNP
#   »/NNP
#   ./.
#   «/VB
#   (PERSON Беларусь/JJ)
#   »/NNP
#   —/NNP
#   «/NNP
#   Эстония/NNP
#   »/NN
#   :/:
#   статистика/JJ
#   личных/NNP
#   встреч/NNP
#   (PERSON Команды/NNP)
#   встречались/NNP
#   между/NNP
#   собой/VBD
#   7/CD
#   раз/NN
#   ./.
#   На/CC
#   счету/JJ
#   сборной/NNP
#   Беларуси/NNP
#   3/CD
#   победы/NNP
#   ,/,
#   сборная/NNP
#   (PERSON Эстонии/NNP)
#   побеждала/NNP
#   в/NNP
#   четырех/NNP
#   матчах/NNP
#   ./.
#   Единственная/VB
#   встреча/JJ
#   в/NNP
#   Беларуси/NNP
#   закончилась/NNP
#   победой/NNP
#   хозяев/NNP
#   со/NNP
#   счетом/NNP
#   1-0.Котировки/JJ
#   букмекерских/NNP
#   контор/NNP
#   БК/NNP
#   Париматч/NNP
#   предлагает/NNP
#   на/NNP
#   этот/NNP
#   матч/NNP
#   следующие/NNP
#   коэффициенты/NN
#   :/:
#   победа/JJ
#   сборной/NNP
#   Беларуси/NNP
#   —/NNP
#   1.52/CD
#   ,/,
#   ничья/NNP
#   –/NNP
#   3.90/CD
#   ,/,
#   победа/NNP
#   сборной/NNP
#   (PERSON Эстонии/NNP)
#   —/VBD
#   8.10/CD
#   ./.
#   «/VB
#   (PERSON Обе/JJ)
#   забьют/NNP
#   »/NNP
#   можно/NNP
#   взять/NNP
#   за/VBD
#   2.50.Прогноз/CD
#   и/NNP
#   ставка/NNP
#   от/NNP
#   (ORGANIZATION BetOn/NNP Сборная/NNP Беларуси/NNP)
#   заслуженно/NNP
#   считается/NNP
#   фаворитом/NNP
#   в/NNP
#   этой/NNP
#   игре/NNP
#   ./.
#   Белорусы/VB
#   провели/JJ
#   неплохие/NNP
#   матчи/NNP
#   в/NNP
#   (PERSON Эстонии/NNP)
#   и/NNP
#   Уэльсе/NNP
#   ./.
#   В/VB
#   составе/JJ
#   нет/NNP
#   глобальных/NNP
#   изменений/NNP
#   ,/,
#   и/NNP
#   болельщики/NNP
#   вправе/NNP
#   ожидать/NNP
#   от/NNP
#   команды/NNP
#   более/NNP
#   слаженной/NNP
#   игры/NNP
#   ./.
#   Белорусские/VB
#   футболисты/JJ
#   выше/NNP
#   классом/NNP
#   ,/,
#   чем/NNP
#   эстонцы/NNP
#   ,/,
#   а/NNP
#   у/NNP
#   гостей/NNP
#   не/NNP
#   будет/NNP
#   их/NNP
#   лучшего/NNP
#   игрока/NNP
#   (PERSON Рагнара/NNP Клавана/NNP)
#   ./.
#   При/VB
#   своих/JJ
#   зрителях/NNP
#   сборная/NNP
#   Беларуси/NNP
#   покажет/NNP
#   атакующую/NNP
#   игру/NNP
#   ./.)
