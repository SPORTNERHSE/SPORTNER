# %%
from string import punctuation
punctuation = punctuation + '—«»'
import pandas as pd
import numpy as np

# %%
text = '''
Россия — русские, россияне, наши
Англия — англичане, британцы
Испания — испанцы
Шахтер  — горняки, кроты, шахта, оранжево-черные
Анже — скоисты, SCO
Аталанта — богиня, оробичи, король-провинциалов, король, провинциалы, короли
Динамо — бело-синие, менты, бобры, мусора, динамики, бело-голубые
Шинник — шина, медведи, резиновые, чёрно-синие
Уфа — уфимцы, горожане
Химки — химари, красно-чёрные, горожане
Норвич Сити — канарейки
Норвича — канарейки
Дармштадт 98 — лилии
Дармштадт — лилии
РБ Лейпциг — быки
Арсенал Тула — канониры, пушкари, самовары, пряники, тульские-пряники, красно-жёлтые, красно-желтые
Рединг — роялисты, обручи, бисквиты, аристократы
Куинз Парк Рейнджерс — обручи, суперобручи, рейнджеры
Куинз Парк — обручи, суперобручи, рейнджеры
Хоффенхайм — сине-белые, Хоффе
Лейпциг — быки
Лестер Сити — лисы, фоссы, синяя-армия, армия 
Лестер — лисы, фоссы, синяя-армия, армия 
Борнмут — вишни, Боскомб
Санкт Паули — пираты
Нюрнберг — клуб, легенды, славные
Мюнхен 1860 — шестидесятники, синие, львы
Мюнхен — шестидесятники, синие, львы
Кристал Пэлас — орлы, стекольщики
Кайзерслаутерн — красные-черти, красные-дьяволы, черти, дьяволы
Ингольштадт 04 — чёрные, защитники-города, защитники
Ингольштадт — чёрные, защитники-города, защитники
Гройтер Фюрт — клеверные, не-поднимающиеся, поднимающиеся 
Гройтер — клеверные, не-поднимающиеся, поднимающиеся
Брайтон энд Хоув Альбион — чайки, курортники, Альбион
Брайтон — чайки, курортники, Альбион
Боруссия Менхенгладбах — жеребцы, жеребята, пони, гладбах, гладбахцы, чёрно-бело-зелёные
Боруссия Дортмунд — BVB, боруссцы, пруссцы, шмели, пчёлы, дортмундские-тигры, тигры, ясельная-группа, ясельники, ясельная
Днепр  — сине-бело-голубые
Металлист — хорьки, металл
Арсенал  — канониры, каштанчики, марсенал, вулидж
Ворскла — ворскляне, зелено-белые
Оболонь — пивовары
Аугсбург — фуггеры
Эльче — зелёно-полосатые, franjiverdes, бело-зелёные, blanquiverdes
Металлург — метадон
Эспаньол — попугаи, канарейки, бело-синие
Спортинг Хихон — красно-белые
Хетафе — городские, испанский-Челси, челси, синие, Хета
Севилья — севильцы, красно-белые, нервионцы
Сельта — кельты, небесно-голубые, небесные, убийца гигантов
Рекреативо — деканы, рекре
Реал Сосьедад — королевский, бело-голубые
Ильичевец  — азовцы, ильичи, ленинцы
Кривбасс — криворожцы
Карпаты  — бандеры, львы
Таврия — крымчане
Черноморец  — одесситы, моряки
Львов — горожане
Харьков — горожане
Леганес —  Lega, Pepineros
Крымтеплица — помидоры
Эйбар — оружейники
Гелиос — солнечные
Севастополь — моряки
Томь — валенки, войлок, томичи, сибиряки, зелёно-белые
Терек — грозненцы, чехи
Спартак-Нальчик — южане, джигиты, гладиаторы, спальчик, спанч, красно-белые
Кордоба — халифы, califas, бело-зелёные, blanquiverdes
Генгам — фермеры, трактористы
Дижон — DFCO, красные
Динамо — бело-голубые, мусора, динамики
Спартак — мясо, свиньи, пищевики, красно-белые, народная-команда, народная, рабы, спартачи
Реал Сарагоса — арагонцы, бланкильос, великолепные
Анжи — дикая-дивизия, дивизия, махачкалинцы, даги, орлы, жёлто-зелёные
Крылья Советов — крылышки, перья, крысы, самарцы, волжане
Луч-Энергия — приморцы, дальневосточники, тигры, фонари
Бордо — аквитанцы, жирондийцы, виноделы, красно-сине-белые, наплечники, клуб-наплечников
Мордовия — бордовые-лисы, бордовые, лисы
ЦСКА — кони, армейцы, красно-синие, лыжники
Амкар  — комбинированные, божьи-коровки, коровки, пермяки, аммиачные, навозники, навоз, пчелы, пчёлы, красно-чёрные, красно-черные
Локомотив — железнодорожники, локо, паровозы, кочегары, красно-зеленые, пятое-колесо, проводницы, проводники, колесо, пятое, лохи, лохомоты
Зенит — бомжи, мешки, сине-бело-голубые, зенитчики, гниды , nits
Ростов — сельмаши, рсм, сельпо, комбайнёры, комбайностроители, зоопарк, осы, свиньи, Русский-Лестер, лестер
Лион — олимпийцы, OL, львы, дети, мальчишки, ткачи
Сатурн — инопланетяне, гуманоиды, гумы
Москва — горожане, кепки, москвичи
Кан — канцы, нормандцы, красно-синие
Урал — уральцы, оранжево-чёрные, шмели
Кубань — казаки, комбайнеры, кубаноиды, канарейки, жабы, жёлто-зелёные, колхозники, команда-лифт, команда-дрифт, лифт, дрифт
Айнтрахт — орлы (Die-Adler), капризная-барышня, капризная-дама, капризная, барышня, дама
Арминия — арминийцы (Die-Armienen), голубые (Die-Blauen)
Боруссия — боруссийцы (Die-Borussen), черно-желтые (Die-Schwarz-Gelben)
Бавария — баварцы, бестия, черные, (Die-Bayern), Голливуд, (Hollywood), красные (Die-Roten), ФКБ, баварцы, мюнхенцы, ФК-Голливуд, красные, красные-штаны, миллионеры, Бавария-Удачи, рекордсмен, звезда-юга, чёрная-бестия
Бавария Мюнхен — баварцы, бестия, черные, (Die-Bayern), Голливуд, (Hollywood), красные (Die-Roten), ФКБ, баварцы, мюнхенцы, ФК-Голливуд, красные, красные-штаны, миллионеры, Бавария-Удачи, рекордсмен, звезда-юга, чёрная-бестия
Байер — аптекари (Die-Apotheker), фармацевты (Die-Pharmazeuten), аспириновые, одиннадцать-рабочих (Die-Werkself), таблетчики, 11-рабочих, заводская-команда, заводская, вицекузен, неверкузен, львы
Вольфсбург — волки (Die-Wlfe), зелёно-белые, автозаводцы
Боруссия — жеребцы (Die-Fohlen), BVB, боруссцы, пруссцы, шмели, пчёлы, дортмундские-тигры, тигры, ясельная-группа, ясельники, ясельная
Вердер — зелено-белые (Die-Grn-Weien), бременские-музыканты (Die-Bremer-Stadtmusikanten), вердерцы (Die-Werderaner), бременцы, везерцы, музыканты, бременские, музыканты, зелёно-белые, Техас, Техас-11
Вердер Бремен — бременцы, везерцы, музыканты, бременские, музыканты, бременские-музыканты, зелёно-белые, Техас, Техас-11, вердерцы
Гамбург — красноштанники (Die-Rothosen), динозавр-бундеслиги (Der-Bundesliga-Dino), ганезеаты (Die-Hanseaten),  горожане, чёрно-синие
Ганновер — девяносто шестые (Die-96er), красные (Die-Roten)
Ганновер 96 — девяносто шестые (Die-96er), красные (Die-Roten)
Герта — старая-дама (Die-alte-Dame)
Герта Берлин — старая-дама (Die-alte-Dame)
Кёльн — козлы (Die-Geibcke), козлята, красно-белые
Бохум — невыбиваемые (Die-Unabsteigbaren), несгибаемые (Die-Unbeugsamen)
Майнц — ноль-пятые (Die-Nullfnfer), карнавальный-клуб (Der-Karnevalsverein), карнавальный, карнавальники, карнавальщики
Майнц 05 — ноль-пятые (Die-Nullfnfer), карнавальный-клуб (Der-Karnevalsverein), карнавальный, карнавальники, карнавальщики
Фрайбург — бразильцы-из-Брайсгау (Die-Breisgau-Brasilianer), бразильцы
Шальке — плуты, кобальтовые (Die-Knigsblauen), горняки (Die-Knappen), гельзенкирхенцы, королевские, синие, королевские-синие, молодые-шахтёры, шахтёры
Шальке-04 — плуты, кобальтовые (Die-Knigsblauen), горняки (Die-Knappen), гельзенкирхенцы, королевские, синие, королевские-синие, молодые-шахтёры, шахтёры
Шальке 04 — плуты, кобальтовые (Die-Knigsblauen), горняки (Die-Knappen), гельзенкирхенцы, королевские, синие, королевские-синие, молодые-шахтёры, шахтёры
Штутгарт — швабы (Die-Schwaben), красные (Die-Roten), автозаводцы
Манчестер-Юнайтед — красные-дьяволы (Red-Devils), дьяволы, малыши-Басби, малыши, Басби, манкунианцы, Man-Ure, Man, Ure, Rags
Манчестер Юнайтед — красные-дьяволы (Red-Devils), дьяволы, малыши-Басби, малыши, Басби, манкунианцы, Man-Ure, Man, Ure, Rags
Манчестер — красные-дьяволы (Red-Devils), дьяволы, малыши-Басби, малыши, Басби, манкунианцы, Man-Ure, Man, Ure, Rags, горожане (Citizens), синие (Blues), сити (City), шейхи, голубая-луна, луна
Арсенал  — канониры, пушкари (Gunners)
Челси — пенсионеры (Pensioners), синие (Blues), аристократы, таксисты, челски, птенцы-Абрамовича, птенцы, Абрамович, rentboys
Астон-Вилла — вилла (Villa), вилланы (Villans), львы, деревня, тюлени
Астон Вилла — вилла (Villa), вилланы (Villans), львы, деревня, тюлени
Вилла — вилла (Villa), вилланы (Villans), львы, деревня, тюлени
Манчестер-Сити — горожане (Citizens), синие (Blues), сити (City), шейхи, голубая-луна, луна
Манчестер Сити — горожане (Citizens), синие (Blues), сити (City), шейхи, голубая-луна, луна
Ливерпуль — красные (Reds), пеликаны, мерсисайдцы, скаузеры
Эвертон — ириски (Toffees), чёрный-дрозд, дрозды, народный-клуб, синие, горчиники, горемыки
Бернли — бордовые (The-Clarets), кларетовые
Тоттенхэм-Хотспур — шпоры (Spurs), лилово-белые (Lilywhites), горячие-головы, горячие, головы, евреи
Тоттенхэм Хотспур — шпоры (Spurs), лилово-белые (Lilywhites), горячие-головы, горячие, головы, евреи
Тоттенхэм — шпоры (Spurs), лилово-белые (Lilywhites), горячие-головы, горячие, головы, евреи
Бирмингем Сити — синие (Blues), синеносые
Бирмингем — синие (Blues), синеносые
Блэкберн Роверс — бродяги (Rovers), сине-белые, риверсайдцы
Блэкберн — бродяги (Rovers), сине-белые, риверсайдцы
Дерби Каунти — бараны
Дерби — бараны
Вест Хэм Юнайтед — молотобойцы, молотки (Hammers), хаммерс, айронс, железные, академия-футбола, академия, кокни, мальчики-кокни
Вест Хэм — молотобойцы, молотки (Hammers), хаммерс, айронс, железные, академия-футбола, академия, кокни, мальчики-кокни
Вулверхэмптон Уондерерс — волки (Wolves), бродяги (Wanderers), старое-золото, золото
Вулверхэмптон — волки (Wolves), бродяги (Wanderers), старое-золото, золото
Болтон Уондерерс — рысаки (Trotters), странники, белые
Болтон — рысаки (Trotters), странники, белые
Портсмут — помпи (Pompey), синяя-армия, армия, синие, турки, skates
Халл Сити — тигры (Tigers)
Халл — тигры (Tigers
Сандерленд — черные-коты (Black-Cats), черные, коты, макемс, рокериты
Сток Сити — гончары (Potters)
Стоук Сити — гончары (Potters)
Уиган Атлетик — латикс (Latics)
Фулхэм — дачники (Cottagers), белые (Whites), коттеджеры
Ноттингем Форест — форест, лесные (Forest), красные (Reds)
Барнсли — дворняги (Tykes)
Саутгемптон — святые (Saints)
Саутхемптон — святые (Saints)
Саутхэмптон — святые (Saints)
Блэкпул — пул (Pool), курортники (Seasiders), мандарины (Tangerines)
Бристоль Роверс — зарянки, дрозды (Robins)
Вест Бромвич Альбион — мешки (Baggies), дрозды (Throstles), Вест Бром (West Brom), Альбион (Albion), боярышники
Вест Бром — мешки (Baggies), дрозды (Throstles), Вест Бром (West-Brom), Альбион (Albion), боярышники
Вест Бромвич — мешки (Baggies), дрозды (Throstles), Вест Бром (West-Brom), Альбион (Albion), боярышники
Кардифф Сити — синие-птицы, синие, птицы, лазурные-птицы, лазурные, синешейки (Bluebirds)
Кардифф — синие-птицы, синие, птицы, лазурные-птицы, лазурные, синешейки (Bluebirds)
Шеффилд Юнайтед — клинки (Blades)
Шеффилд — клинки (Blades)
Ковентри Сити — небесно-голубые (Sky-Blues), сити (City)
Мидлсбро — боро (Boro), смогги (Smoggies), речники, красная-армия, тисайдцы, красная, армия
Ньюкасл Юнайтед — сороки (Magpies), тун (Toon), джорди, чёрно-белые
Ньюкасл — сороки (Magpies), тун (Toon), джорди, чёрно-белые
Плимут Аргайл — пилигримы (Pilgrims), зеленые (Greens), зеленая-армия (Green-Army)
Суонси Сити — лебеди (Swans), матросы (Jacks)
Суонси — лебеди (Swans), матросы (Jacks)
Уотфорд — шершни (Hornets), рога (Horns), золотые-мальчики, золотые, мальчики, жёлтая-армия, желтая, армия
Шеффилд Уэнсдей — совы (Owls), среда
Оренбург — горожане
Шеффилд — совы (Owls), среда
Сампдория — генуэзцы, лигурийцы, Самп, Дория, моряки, блючеркьятти
Удинезе — удинцы, фрриульцы, чёрно-белые, бьянконери, зебры
Сассуоло — чёрно-зелёные
Эмполи — синие
Наполи — неаполитанцы, кампанийцы, партенопейцы, голубые, адзурри, маленькие-ослы, маленькие, ослы
Интер — гадюки (Biscioni), нерадзурри, черно-синие, клуб-побитых, побитые, любимчики, народная-команда, ломбардийцы, хвастуны, хвастливые-миланцы, хвастливые, миланцы, змеи, интеристы, мерда
Интер Милан — нерадзурри, черно-синие, клуб-побитых, побитые, любимчики, народная-команда, ломбардийцы, хвастуны, хвастливые-миланцы, хвастливые, миланцы, змеи, интеристы, мерда
Милан — красно-черные, россонери, красно-чёрные, дьяволы, красные-дьяволы, красные, голландское, пристанище, голландское-пристанище, старики, гаечные-ключи, гаечные, ключи
Ювентус — бело-черные, старая-синьора, синьора, синьера, чёрно-белые, бьянконери, зебры, гоббы, Госпожа-Убийца, госпожа, пьемонтцы, Юве, Подруга-Италии, подруга, Невеста-Италии, невеста
Фиорентина — фиалки, флорентийцы, тосканцы, фиолетовые, лилии
Рома — джеларосси, римляне, романиста, джаллароси, жёлто-красные, волки, магическая-команда, евреи, магическая
Кротоне — пифагорейцы, акулы, красно-синие
Лацио — небесно-голубые, орлы, римляне, лациале, бело-небесно-голубые,бьянкочелести, бело-голубые, бьянкадзурри, орлята, фашисты
Парма — молочники, пармезанцы, дети-герцога, дети, герцога, ветчина, мясники, жёлто-синие, крестоносцы
Торино — скуадра, граната, бьянконери, зебры, бордовые, гранатовые, гранатовая-команда, быки
Дженоа —  генуэзцы, лигурийцы, грифоны, красно-синие, старые-шутники, старые, шутники, англичане
Геноа — генуэзцы, лигурийцы, грифоны, красно-синие, старые-шутники, старые, шутники, англичане
Пескара — дельфины, бело-голубые
Кальяри — сардинцы, красно-синие, островитяне, сардинийцы
Гранада — Насриды, Грана, красно-белые
Верона — греки, эллины, Скалигеры, жёлто-синие, мастифы
Реджина — южане
Бари — петухи
Лечче — кетчупс
Болонья — россоблу, красно-синие
Реал Овьедо — синие, Карбайонцы, Carbayones
Кьево — летающие-ослы, джиалоблу, летающие, ослы, Кьео, жёлто-голубые, джаллоблу
Брешиа — ласточки (Rondinelle)
Перуджа — грифы
Палермо — розанеро, розово-чёрные, орлы
Ливорно — аморанте
Реал Бетис — огурцы, зеленушка, бело-зелённые
Депортиво — Депор, ла-корунцы, галисийцы, бело-голубые, турки
Реал Мадрид — галактикос, сливочные, королевский-клуб, сливочные, белые, бланкос, меренги, пастухи, мадридисты, овцы
Реал — галактикос, сливочные, королевский-клуб
Барселона — сине-гранатовые, гранатово-синие, горячие-задницы, барса, блауграна, каталонцы, задницы, ягодицы
Валенсия — летучие мыши, бэтмены, валенсийцы, Чес, оранжевые
Атлетико Мадрид — матрасники, матрасы, индейцы
Атлетико — матрасники, матрасы, индейцы
Вильярреал — желтая-подводная-лодка, подводная-лодка, жёлтая-субмарина, подводники
Алавес — баски, лисы, los-babazorros, славные, прославленные, розовая-команда
Мальорка — болеарцы
Малага — медузы, анчоусы, бело-синие
Бетис — бетикос
Леванты — лягушки
Леванте — лягушки
Кадис — дятлы, жёлтая-подводная-лодка
Лас-Пальмас — пальмы, жёлтые
Мурсия — красные-перцы
Тенерифе — пьяницы
Бенфика  — орлы
Порту — драконы
Спортинг  — львы
Омниворлд — чёрные-овцы
Фейеноорд — докеры
Аякс — божьи дети
Граафсхап — суперфермеры (Superboeren)
Го Эхед — суперорлы
НАК — крысы
Жерминаль — крысы
Мускрон — харлас
Андерлехт — лиловые, сиреневые
Генк — шахтеры
Брюгге — газели
Брюссель — коалы, трехцветные
Шарлеруа — зебры
Сент-Трюйден — канарейки
Харельбекке — крысы (Ratten)
Пари-Сен-Жермен — принцы, парижане, столичные, красно-синие
Лорьян — морские-щуки, щуки, мерлузовые, оранжево-черные
Пари Сен-Жермен — парижане, столичные, красно-синие, принцы
ПСЖ — парижане, столичные, красно-синие, принцы
Реймс — красно-белые
Нант — канарейки, жёлто-зелёные
Тулуза — малыши, фиалки
Труа — фермеры, синие
Седан — кабаны
Бордо — виноделы, жирондинцы
Нанси — чертопо лохи, ASNL
Бастия — островитяне, синие
Монако — монегаски, красно-белые
Лилль — доги, боксёры, красно-синие
Аяччо — медведи
Ренн — чернокожие, красно-чёрные, бретонцы
Сошо — львы
Сент-Этьен — зеленые, ASSE, Stéphanois
Ницца — орлята, гимнасты, l'OGCN,красно-чёрные
Монпелье — паладины, MHSC
Геньон — кузнецы
Денизлиспор — петухи
Лозанна Спортс — ночные короли
Грасхопперс — кузнечики
БАТЭ — желто-синие, борисовчане, батоны
Неман — желто-зелёные
Шахтер — горняки, солигорцы
Райо Вальекано —  пчёлы, Райо, молнии, красно-полосатые
МТЗ-РИПО — трактористы, тракторозаводцы, мрази
Марсель — марсельцы, провансальцы, южане, олимпийцы, OM, арабы, бело-голубые
Метц — тёмно-бордовые, мессинцы, Граулли
Динамо — бело-синие
Осасуна — красные, красненькие, рохильос, памплонцы
Витебск — горожане, витебляне
Бока Хуниорс — генуэзцы (Los-Xeneizes), бостерос (Los-Bosteros), кубковые-короли (El-Rey-de-Copas), сине-золотые
Ривер Плейт — миллионеры (Los-Millonarios, El-Millo), ла-банда (La-Banda), полосатые, курицы, цыплята 
Индепендьенте — красные (Rojos), дьяволы (Diablos), красные-дьяволы (Diablos-Rojos), гордость-Аргентины (El-Orgulo-Nacional)
Пеньяроль — жёлто-чёрные (Aurinegros), карбонерос (Carboneros), маниас (Manyas), мирасолес (Mirasoles)
Насьональ — больсос, карманы (Bolsos), трёхцветные (Tricolores), белые (Albos), больсильюдос (Bolsilludos)
Америка — мекао (Mecao), драконы (Dragao)
Гремио — трёхцветные (Tricolor), Гаучос (Gauchos)
Жувентуд — жу (Ju), Попугаи (Periquito), Толстые, Жирные, Обжоры, Papo, Papado
Атлетико  — петухи (Galo), альвинегро, бело-чёрные (Alvinegro)
Итуано — петухи (Galo), рубронегро, красно-чёрные (Rubronegro)
Атлетико — Ураганы (Furacao), рубронегро, красно-чёрные (Rubronegro)
КРБ — Регатеано (Regateano), пляжные петухи (Galo-da-Praia)
Clube de Regatas Brasil — Регатеано (Regateano), пляжные петухи (Galo-da-Praia)
Крузейро — небожители (Celestes), лисы (Raposa)
Ремо — львы (Leao), голубые (Azulinho)
Интернасьонал — колорадо, красные (Colorado)
Витория — львы-с-Барра (Leao-da-Barra), львы
Атлетик Бильбао — красно-белые, баски, львы
Санта Круз — коралловые-аспиды (Cobra-Coral), кораллы (Coral)
Бразильенсе — аллигаторы (Jacare)
Португеза — португальцы (Lusa)
Португалия — португальцы
Паулиста — петухи (Galo-do-Japi), трёхцветные-из-Жундиая (Tricolor-Jundiaense)
Форталеза — львы (Leao), стальные-трёхцветные (Tricolor-de-Aco), мальчишки (Clube-da-Garotada)
Наутико — опоссумы (Timbu), альвирубро, бело-красные (Alvirubro)
Паранья — лазурные-сойки (Gralha-Azul), трёхцветные-с-Вила-Капанема (Tricolor-da-Vila-Capanema)
Палмейрас — свиньи (Porco), вердао (Verdao), альвиверде, бело-зелёные (Alviverde)
Марилия — тигры (Tigre), тиграо, тигрищи (Tigrao), Альвиселесте, Бело-небесные (Alviceleste)
Коринтианс — командища (Timao), корингао (Coringao), Мушкетёры (Mosqueteiro), чемпион-чемпионов (Campeao-dos-Campeaes)
Коритиба — белоногие (Coxa Branca), вердао (Verdao, альвиверде, бело-зелёные (Alviverde), кори (Cori)
Фламенго — Фла, Менго (Fla, Mengo), рубронегро, красно-чёрные (Rubronegro), стервятники (Urubu)
Сантос — рыбы (Peixe), сантастико (Santastico)
Сан Каэтано — азулао (Azulao)
Понте Прета — макаки (Macaca)
Сан Паулу — трёхцветные-из-Сан Паулу (Tricolor-Paulista), трёхцветные
Ботафого (Рио-Де-Жанейро) — фого, бота (Fogo,  Bota), огонище (Fogao), альвинегро, бело-чёрные (Alvinegro), Одинокая-звезда (Estrela-Solitaria), выдающиеся, блестящие (Glorioso)
Гама — Гамао (Gamao), альвиверде, бело-зелёные (Alviverde), вердао (Verdao)
Гойяс — попугаи (Periquito), вердао (Verdao), Эсмералдиньо, Изумрудные (Esmeraldinho)
Динамо — голубые львы
Хайдук — морские ассы
Вартекс — портные
Загреб — поэты
Црвена Звезда — цыгане
Црвена — цыгане
Нови Сад — канарейки
ОФК Белград — романтики
Партизан — могильщики
Обилич — витязи
Бразилия — канаринья
Краснодар — горожане, быки, черные-буйволы, буйволы, кастраты, магниты, черно-зеленые
Аргентина — альбиселеста
Италия — лазурная-эскадра, скуадра-адзурра, макаронники, итальянцы
Швеция — три-короны, тре-крунер, викинги, шведы
Австралия — соккеруз, кенгуру
Парагвай — гуарани
Рубин — рубины, рубиновые, казанцы, татары
Сибирь — орлы, сине-белые, сибирцы
Насьональ — больсос, карманы, (Bolsos), трёхцветные (Tricolores), белые (Albos), больсильюдос (Bolsilludos)
Авай — островные-львы (Leao-da-Ilha)
Америка — мекао (Mecao), драконы (Dragao)
Гремио — трёхцветные (Tricolor), Гаучос (Gauchos)
Атлетико (Минейро) — петухи (Galo), альвинегро, бело-чёрные (Alvinegro)
Итуано — петухи (Galo), рубронегро, красно-чёрные (Rubronegro)
Атлетико — Ураганы (Furacao), рубронегро, красно-чёрные (Rubronegro)
Васко да Гама — васкао (Vascao), гиганты-с-холма (Gigante-da-Colina), треска (Bacalhau), мальтийский-крест (Clube-da-Cruz-de-Malta), чёрные рубашки (Os Camisas Pretas)
Динамо (Загреб) — голубые-львы
Хайдук — морские-ассы
Вартекс — портные
Загреб — поэты
Црвена Звезда — цыгане
Нови-Сад — канарейки
ОФК-Белград — романтики
Партизан — могильщики
Обилич — витязи
Бразилия — канаринья, бразильцы
Аргентина — альбиселеста, аргентинцы
Австралия — соккеруз, кенгуру, австралийцы
Парагвай — гуарани
Мексика — ацтеки, мексиканцы
Перу — инки
Венесуэла — чарруас
США — янки, американцы, америкосы
Египет — фараоны, египтяне
Камерун — неукротимые-львы, камерунцы
Турция — янычары, турки
ЮАР — Бафана-Бафана, африканцы
Либерия — одинокая звезда
Нигерия — суперорлы, нигерийцы
Голландия — оранжевые, голландцы, нидерландцы
Нидерланды — оранжевые, голландцы, нидерландцы
Швейцария — сырники, швейцарцы
Норвегия — норманы, норвежцы
Франция — лягушатники, трехцветные, мушкетеры, петушки, французы, французики
Гана — черные-звезды
Кот-д'Ивуар — слоны
Люксембург — банкиры, люксембургцы
Бразилия — пентакампеоны, кудесники-мяча, желтые, горожане-Рио, бразильцы
Германия — Дие-Маншафт
Тринидад и Тобаго — футбольные воины
Конго — леопарды
Дания — датский-динамит, датчане
Уэльс — валлийцы, красные-драконы, вареные-ящерицы
Бельгия — красные-дьяволы, бельгийцы
Хорватия — жгучие-парни, хорваты
Пуэрто-Рико — ковбои, пуэрориканцы
Ямайка — рэгги-бойз'''

# %% [markdown]
# ## dicttolist

# %%
class Dictlist(dict):
    def __setitem__(self, key, value):
        try:
            self[key]
        except KeyError:
            super(Dictlist, self).__setitem__(key, [])
        self[key].append(value)

# %%
dict2 = Dictlist()

# %%
for sentence in text.split('\n'):
    for i,part in enumerate(sentence.split('—')):
        if i == 0 :
            #real_name = part.split()[0]
            real_name = part.strip()
            real_name = real_name.lower()
            #print(real_name, '1')
            #print(real_name)
        if i == 1:
            aliases = [w.strip(punctuation) for w in part.split()]
            #print(aliases)
            for alias in aliases:
                #print(real_name)
                #print(aliase, '3')
                alias = alias.lower()
                dict2[alias] = real_name

# %%
dict2
# Out:
# {'русские': ['россия'],
#  'россияне': ['россия'],
#  'наши': ['россия'],
#  'англичане': ['англия', 'дженоа', 'геноа'],
#  'британцы': ['англия'],
#  'испанцы': ['испания'],
#  'горняки': ['шахтер', 'шальке', 'шальке-04', 'шальке 04', 'шахтер'],
#  'кроты': ['шахтер'],
#  'шахта': ['шахтер'],
#  'оранжево-черные': ['шахтер', 'лорьян'],
#  'скоисты': ['анже'],
#  'sco': ['анже'],
#  'богиня': ['аталанта'],
#  'оробичи': ['аталанта'],
#  'король-провинциалов': ['аталанта'],
#  'король': ['аталанта'],
#  'провинциалы': ['аталанта'],
#  'короли': ['аталанта', 'лозанна спортс'],
#  'бело-синие': ['динамо', 'эспаньол', 'малага', 'динамо'],
#  'менты': ['динамо'],
#  'бобры': ['динамо'],
#  'мусора': ['динамо', 'динамо'],
#  'динамики': ['динамо', 'динамо'],
#  'бело-голубые': ['динамо',
#   'реал сосьедад',
#   'динамо',
#   'лацио',
#   'пескара',
#   'депортиво',
#   'марсель'],
#  'шина': ['шинник'],
#  'медведи': ['шинник', 'аяччо'],
#  'резиновые': ['шинник'],
#  'чёрно-синие': ['шинник', 'гамбург'],
#  'уфимцы': ['уфа'],
#  'горожане': ['уфа',
#   'химки',
#   'львов',
#   'харьков',
#   'москва',
#   'гамбург',
#   'манчестер',
#   'манчестер-сити',
#   'манчестер сити',
#   'оренбург',
#   'витебск',
#   'краснодар'],
#  'химари': ['химки'],
#  'красно-чёрные': ['химки',
#   'амкар',
#   'милан',
#   'ренн',
#   'итуано',
#   'атлетико',
#   'фламенго',
#   'итуано',
#   'атлетико'],
#  'канарейки': ['норвич сити',
#   'норвича',
#   'эспаньол',
#   'кубань',
#   'сент-трюйден',
#   'нант',
#   'нови сад',
#   'нови-сад'],
#  'лилии': ['дармштадт 98', 'дармштадт', 'фиорентина'],
#  'быки': ['рб лейпциг', 'лейпциг', 'торино', 'краснодар'],
#  'канониры': ['арсенал тула', 'арсенал', 'арсенал'],
#  'пушкари': ['арсенал тула', 'арсенал'],
#  'самовары': ['арсенал тула'],
#  'пряники': ['арсенал тула'],
#  'тульские-пряники': ['арсенал тула'],
#  'красно-жёлтые': ['арсенал тула'],
#  'красно-желтые': ['арсенал тула'],
#  'роялисты': ['рединг'],
#  'обручи': ['рединг', 'куинз парк рейнджерс', 'куинз парк'],
#  'бисквиты': ['рединг'],
#  'аристократы': ['рединг', 'челси'],
#  'суперобручи': ['куинз парк рейнджерс', 'куинз парк'],
#  'рейнджеры': ['куинз парк рейнджерс', 'куинз парк'],
#  'сине-белые': ['хоффенхайм', 'блэкберн роверс', 'блэкберн', 'сибирь'],
#  'хоффе': ['хоффенхайм'],
#  'лисы': ['лестер сити', 'лестер', 'мордовия', 'алавес', 'крузейро'],
#  'фоссы': ['лестер сити', 'лестер'],
#  'синяя-армия': ['лестер сити', 'лестер', 'портсмут'],
#  'армия': ['лестер сити', 'лестер', 'портсмут', 'мидлсбро', 'уотфорд'],
#  'вишни': ['борнмут'],
#  'боскомб': ['борнмут'],
#  'пираты': ['санкт паули'],
#  'клуб': ['нюрнберг'],
#  'легенды': ['нюрнберг'],
#  'славные': ['нюрнберг', 'алавес'],
#  'шестидесятники': ['мюнхен 1860', 'мюнхен'],
#  'синие': ['мюнхен 1860',
#   'мюнхен',
#   'хетафе',
#   'шальке',
#   'шальке-04',
#   'шальке 04',
#   'манчестер',
#   'челси',
#   'манчестер-сити',
#   'манчестер сити',
#   'эвертон',
#   'бирмингем сити',
#   'бирмингем',
#   'портсмут',
#   'кардифф сити',
#   'кардифф',
#   'эмполи',
#   'реал овьедо',
#   'труа',
#   'бастия'],
#  'львы': ['мюнхен 1860',
#   'мюнхен',
#   'карпаты',
#   'лион',
#   'байер',
#   'астон-вилла',
#   'астон вилла',
#   'вилла',
#   'спортинг',
#   'сошо',
#   'ремо',
#   'витория',
#   'атлетик бильбао',
#   'форталеза',
#   'динамо'],
#  'орлы': ['кристал пэлас',
#   'анжи',
#   'айнтрахт',
#   'лацио',
#   'палермо',
#   'бенфика',
#   'сибирь'],
#  'стекольщики': ['кристал пэлас'],
#  'красные-черти': ['кайзерслаутерн'],
#  'красные-дьяволы': ['кайзерслаутерн',
#   'манчестер-юнайтед',
#   'манчестер юнайтед',
#   'манчестер',
#   'милан',
#   'индепендьенте',
#   'бельгия'],
#  'черти': ['кайзерслаутерн'],
#  'дьяволы': ['кайзерслаутерн',
#   'манчестер-юнайтед',
#   'манчестер юнайтед',
#   'манчестер',
#   'милан',
#   'индепендьенте'],
#  'чёрные': ['ингольштадт 04', 'ингольштадт', 'васко да гама'],
#  'защитники-города': ['ингольштадт 04', 'ингольштадт'],
#  'защитники': ['ингольштадт 04', 'ингольштадт'],
#  'клеверные': ['гройтер фюрт', 'гройтер'],
#  'не-поднимающиеся': ['гройтер фюрт', 'гройтер'],
#  'поднимающиеся': ['гройтер фюрт', 'гройтер'],
#  'чайки': ['брайтон энд хоув альбион', 'брайтон'],
#  'курортники': ['брайтон энд хоув альбион', 'брайтон', 'блэкпул'],
#  'альбион': ['брайтон энд хоув альбион',
#   'брайтон',
#   'вест бромвич альбион',
#   'вест бром',
#   'вест бромвич'],
#  'жеребцы': ['боруссия менхенгладбах', 'боруссия'],
#  'жеребята': ['боруссия менхенгладбах'],
#  'пони': ['боруссия менхенгладбах'],
#  'гладбах': ['боруссия менхенгладбах'],
#  'гладбахцы': ['боруссия менхенгладбах'],
#  'чёрно-бело-зелёные': ['боруссия менхенгладбах'],
#  'bvb': ['боруссия дортмунд', 'боруссия'],
#  'боруссцы': ['боруссия дортмунд', 'боруссия'],
#  'пруссцы': ['боруссия дортмунд', 'боруссия'],
#  'шмели': ['боруссия дортмунд', 'урал', 'боруссия'],
#  'пчёлы': ['боруссия дортмунд', 'амкар', 'боруссия', 'райо вальекано'],
#  'дортмундские-тигры': ['боруссия дортмунд', 'боруссия'],
#  'тигры': ['боруссия дортмунд',
#   'луч-энергия',
#   'боруссия',
#   'халл сити',
#   'халл',
#   'марилия'],
#  'ясельная-группа': ['боруссия дортмунд', 'боруссия'],
#  'ясельники': ['боруссия дортмунд', 'боруссия'],
#  'ясельная': ['боруссия дортмунд', 'боруссия'],
#  'сине-бело-голубые': ['днепр', 'зенит'],
#  'хорьки': ['металлист'],
#  'металл': ['металлист'],
#  'каштанчики': ['арсенал'],
#  'марсенал': ['арсенал'],
#  'вулидж': ['арсенал'],
#  'ворскляне': ['ворскла'],
#  'зелено-белые': ['ворскла', 'вердер'],
#  'пивовары': ['оболонь'],
#  'фуггеры': ['аугсбург'],
#  'зелёно-полосатые': ['эльче'],
#  'franjiverdes': ['эльче'],
#  'бело-зелёные': ['эльче', 'кордоба', 'палмейрас', 'коритиба', 'гама'],
#  'blanquiverdes': ['эльче', 'кордоба'],
#  'метадон': ['металлург'],
#  'попугаи': ['эспаньол', 'жувентуд', 'гойяс'],
#  'красно-белые': ['спортинг хихон',
#   'севилья',
#   'спартак-нальчик',
#   'спартак',
#   'кёльн',
#   'гранада',
#   'реймс',
#   'монако',
#   'атлетик бильбао'],
#  'городские': ['хетафе'],
#  'испанский-челси': ['хетафе'],
#  'челси': ['хетафе'],
#  'хета': ['хетафе'],
#  'севильцы': ['севилья'],
#  'нервионцы': ['севилья'],
#  'кельты': ['сельта'],
#  'небесно-голубые': ['сельта', 'ковентри сити', 'лацио'],
#  'небесные': ['сельта'],
#  'убийца': ['сельта'],
#  'гигантов': ['сельта'],
#  'деканы': ['рекреативо'],
#  'рекре': ['рекреативо'],
#  'королевский': ['реал сосьедад'],
#  'азовцы': ['ильичевец'],
#  'ильичи': ['ильичевец'],
#  'ленинцы': ['ильичевец'],
#  'криворожцы': ['кривбасс'],
#  'бандеры': ['карпаты'],
#  'крымчане': ['таврия'],
#  'одесситы': ['черноморец'],
#  'моряки': ['черноморец', 'севастополь', 'сампдория'],
#  'lega': ['леганес'],
#  'pepineros': ['леганес'],
#  'помидоры': ['крымтеплица'],
#  'оружейники': ['эйбар'],
#  'солнечные': ['гелиос'],
#  'валенки': ['томь'],
#  'войлок': ['томь'],
#  'томичи': ['томь'],
#  'сибиряки': ['томь'],
#  'зелёно-белые': ['томь', 'вольфсбург', 'вердер', 'вердер бремен'],
#  'грозненцы': ['терек'],
#  'чехи': ['терек'],
#  'южане': ['спартак-нальчик', 'реджина', 'марсель'],
#  'джигиты': ['спартак-нальчик'],
#  'гладиаторы': ['спартак-нальчик'],
#  'спальчик': ['спартак-нальчик'],
#  'спанч': ['спартак-нальчик'],
#  'халифы': ['кордоба'],
#  'califas': ['кордоба'],
#  'фермеры': ['генгам', 'труа'],
#  'трактористы': ['генгам', 'мтз-рипо'],
#  'dfco': ['дижон'],
#  'красные': ['дижон',
#   'бавария',
#   'бавария',
#   'бавария мюнхен',
#   'бавария мюнхен',
#   'ганновер',
#   'ганновер 96',
#   'штутгарт',
#   'ливерпуль',
#   'ноттингем форест',
#   'милан',
#   'осасуна',
#   'индепендьенте',
#   'интернасьонал'],
#  'мясо': ['спартак'],
#  'свиньи': ['спартак', 'ростов', 'палмейрас'],
#  'пищевики': ['спартак'],
#  'народная-команда': ['спартак', 'интер', 'интер милан'],
#  'народная': ['спартак'],
#  'рабы': ['спартак'],
#  'спартачи': ['спартак'],
#  'арагонцы': ['реал сарагоса'],
#  'бланкильос': ['реал сарагоса'],
#  'великолепные': ['реал сарагоса'],
#  'дикая-дивизия': ['анжи'],
#  'дивизия': ['анжи'],
#  'махачкалинцы': ['анжи'],
#  'даги': ['анжи'],
#  'жёлто-зелёные': ['анжи', 'кубань', 'нант'],
#  'крылышки': ['крылья советов'],
#  'перья': ['крылья советов'],
#  'крысы': ['крылья советов', 'нак', 'жерминаль', 'харельбекке'],
#  'самарцы': ['крылья советов'],
#  'волжане': ['крылья советов'],
#  'приморцы': ['луч-энергия'],
#  'дальневосточники': ['луч-энергия'],
#  'фонари': ['луч-энергия'],
#  'аквитанцы': ['бордо'],
#  'жирондийцы': ['бордо'],
#  'виноделы': ['бордо', 'бордо'],
#  'красно-сине-белые': ['бордо'],
#  'наплечники': ['бордо'],
#  'клуб-наплечников': ['бордо'],
#  'бордовые-лисы': ['мордовия'],
#  'бордовые': ['мордовия', 'бернли', 'торино'],
#  'кони': ['цска'],
#  'армейцы': ['цска'],
#  'красно-синие': ['цска',
#   'кан',
#   'кротоне',
#   'дженоа',
#   'геноа',
#   'кальяри',
#   'болонья',
#   'пари-сен-жермен',
#   'пари сен-жермен',
#   'псж',
#   'лилль'],
#  'лыжники': ['цска'],
#  'комбинированные': ['амкар'],
#  'божьи-коровки': ['амкар'],
#  'коровки': ['амкар'],
#  'пермяки': ['амкар'],
#  'аммиачные': ['амкар'],
#  'навозники': ['амкар'],
#  'навоз': ['амкар'],
#  'пчелы': ['амкар'],
#  'красно-черные': ['амкар', 'милан'],
#  'железнодорожники': ['локомотив'],
#  'локо': ['локомотив'],
#  'паровозы': ['локомотив'],
#  'кочегары': ['локомотив'],
#  'красно-зеленые': ['локомотив'],
#  'пятое-колесо': ['локомотив'],
#  'проводницы': ['локомотив'],
#  'проводники': ['локомотив'],
#  'колесо': ['локомотив'],
#  'пятое': ['локомотив'],
#  'лохи': ['локомотив', 'нанси'],
#  'лохомоты': ['локомотив'],
#  'бомжи': ['зенит'],
#  'мешки': ['зенит', 'вест бромвич альбион', 'вест бром', 'вест бромвич'],
#  'зенитчики': ['зенит'],
#  'гниды': ['зенит'],
#  '': ['зенит'],
#  'nits': ['зенит'],
#  'сельмаши': ['ростов'],
#  'рсм': ['ростов'],
#  'сельпо': ['ростов'],
#  'комбайнёры': ['ростов'],
#  'комбайностроители': ['ростов'],
#  'зоопарк': ['ростов'],
#  'осы': ['ростов'],
#  'русский-лестер': ['ростов'],
#  'лестер': ['ростов'],
#  'олимпийцы': ['лион', 'марсель'],
#  'ol': ['лион'],
#  'дети': ['лион', 'парма', 'аякс'],
#  'мальчишки': ['лион', 'форталеза'],
#  'ткачи': ['лион'],
#  'инопланетяне': ['сатурн'],
#  'гуманоиды': ['сатурн'],
#  'гумы': ['сатурн'],
#  'кепки': ['москва'],
#  'москвичи': ['москва'],
#  'канцы': ['кан'],
#  'нормандцы': ['кан'],
#  'уральцы': ['урал'],
#  'оранжево-чёрные': ['урал'],
#  'казаки': ['кубань'],
#  'комбайнеры': ['кубань'],
#  'кубаноиды': ['кубань'],
#  'жабы': ['кубань'],
#  'колхозники': ['кубань'],
#  'команда-лифт': ['кубань'],
#  'команда-дрифт': ['кубань'],
#  'лифт': ['кубань'],
#  'дрифт': ['кубань'],
#  'die-adler': ['айнтрахт'],
#  'капризная-барышня': ['айнтрахт'],
#  'капризная-дама': ['айнтрахт'],
#  'капризная': ['айнтрахт'],
#  'барышня': ['айнтрахт'],
#  'дама': ['айнтрахт'],
#  'арминийцы': ['арминия'],
#  'die-armienen': ['арминия'],
#  'голубые': ['арминия', 'наполи', 'ремо', 'динамо'],
#  'die-blauen': ['арминия'],
#  'боруссийцы': ['боруссия'],
#  'die-borussen': ['боруссия'],
#  'черно-желтые': ['боруссия'],
#  'die-schwarz-gelben': ['боруссия'],
#  'баварцы': ['бавария', 'бавария', 'бавария мюнхен', 'бавария мюнхен'],
#  'бестия': ['бавария', 'бавария мюнхен'],
#  'черные': ['бавария', 'бавария мюнхен', 'сандерленд'],
#  'die-bayern': ['бавария', 'бавария мюнхен'],
#  'голливуд': ['бавария', 'бавария мюнхен'],
#  'hollywood': ['бавария', 'бавария мюнхен'],
#  'die-roten': ['бавария',
#   'бавария мюнхен',
#   'ганновер',
#   'ганновер 96',
#   'штутгарт'],
#  'фкб': ['бавария', 'бавария мюнхен'],
#  'мюнхенцы': ['бавария', 'бавария мюнхен'],
#  'фк-голливуд': ['бавария', 'бавария мюнхен'],
#  'красные-штаны': ['бавария', 'бавария мюнхен'],
#  'миллионеры': ['бавария', 'бавария мюнхен', 'ривер плейт'],
#  'бавария-удачи': ['бавария', 'бавария мюнхен'],
#  'рекордсмен': ['бавария', 'бавария мюнхен'],
#  'звезда-юга': ['бавария', 'бавария мюнхен'],
#  'чёрная-бестия': ['бавария', 'бавария мюнхен'],
#  'аптекари': ['байер'],
#  'die-apotheker': ['байер'],
#  'фармацевты': ['байер'],
#  'die-pharmazeuten': ['байер'],
#  'аспириновые': ['байер'],
#  'одиннадцать-рабочих': ['байер'],
#  'die-werkself': ['байер'],
#  'таблетчики': ['байер'],
#  '11-рабочих': ['байер'],
#  'заводская-команда': ['байер'],
#  'заводская': ['байер'],
#  'вицекузен': ['байер'],
#  'неверкузен': ['байер'],
#  'волки': ['вольфсбург', 'вулверхэмптон уондерерс', 'вулверхэмптон', 'рома'],
#  'die-wlfe': ['вольфсбург'],
#  'автозаводцы': ['вольфсбург', 'штутгарт'],
#  'die-fohlen': ['боруссия'],
#  'die-grn-weien': ['вердер'],
#  'бременские-музыканты': ['вердер', 'вердер бремен'],
#  'die-bremer-stadtmusikanten': ['вердер'],
#  'вердерцы': ['вердер', 'вердер бремен'],
#  'die-werderaner': ['вердер'],
#  'бременцы': ['вердер', 'вердер бремен'],
#  'везерцы': ['вердер', 'вердер бремен'],
#  'музыканты': ['вердер', 'вердер', 'вердер бремен', 'вердер бремен'],
#  'бременские': ['вердер', 'вердер бремен'],
#  'техас': ['вердер', 'вердер бремен'],
#  'техас-11': ['вердер', 'вердер бремен'],
#  'красноштанники': ['гамбург'],
#  'die-rothosen': ['гамбург'],
#  'динозавр-бундеслиги': ['гамбург'],
#  'der-bundesliga-dino': ['гамбург'],
#  'ганезеаты': ['гамбург'],
#  'die-hanseaten': ['гамбург'],
#  'девяносто': ['ганновер', 'ганновер 96'],
#  'шестые': ['ганновер', 'ганновер 96'],
#  'die-96er': ['ганновер', 'ганновер 96'],
#  'старая-дама': ['герта', 'герта берлин'],
#  'die-alte-dame': ['герта', 'герта берлин'],
#  'козлы': ['кёльн'],
#  'die-geibcke': ['кёльн'],
#  'козлята': ['кёльн'],
#  'невыбиваемые': ['бохум'],
#  'die-unabsteigbaren': ['бохум'],
#  'несгибаемые': ['бохум'],
#  'die-unbeugsamen': ['бохум'],
#  'ноль-пятые': ['майнц', 'майнц 05'],
#  'die-nullfnfer': ['майнц', 'майнц 05'],
#  'карнавальный-клуб': ['майнц', 'майнц 05'],
#  'der-karnevalsverein': ['майнц', 'майнц 05'],
#  'карнавальный': ['майнц', 'майнц 05'],
#  'карнавальники': ['майнц', 'майнц 05'],
#  'карнавальщики': ['майнц', 'майнц 05'],
#  'бразильцы-из-брайсгау': ['фрайбург'],
#  'die-breisgau-brasilianer': ['фрайбург'],
#  'бразильцы': ['фрайбург', 'бразилия', 'бразилия'],
#  'плуты': ['шальке', 'шальке-04', 'шальке 04'],
#  'кобальтовые': ['шальке', 'шальке-04', 'шальке 04'],
#  'die-knigsblauen': ['шальке', 'шальке-04', 'шальке 04'],
#  'die-knappen': ['шальке', 'шальке-04', 'шальке 04'],
#  'гельзенкирхенцы': ['шальке', 'шальке-04', 'шальке 04'],
#  'королевские': ['шальке', 'шальке-04', 'шальке 04'],
#  'королевские-синие': ['шальке', 'шальке-04', 'шальке 04'],
#  'молодые-шахтёры': ['шальке', 'шальке-04', 'шальке 04'],
#  'шахтёры': ['шальке', 'шальке-04', 'шальке 04'],
#  'швабы': ['штутгарт'],
#  'die-schwaben': ['штутгарт'],
#  'red-devils': ['манчестер-юнайтед', 'манчестер юнайтед', 'манчестер'],
#  'малыши-басби': ['манчестер-юнайтед', 'манчестер юнайтед', 'манчестер'],
#  'малыши': ['манчестер-юнайтед', 'манчестер юнайтед', 'манчестер', 'тулуза'],
#  'басби': ['манчестер-юнайтед', 'манчестер юнайтед', 'манчестер'],
#  'манкунианцы': ['манчестер-юнайтед', 'манчестер юнайтед', 'манчестер'],
#  'man-ure': ['манчестер-юнайтед', 'манчестер юнайтед', 'манчестер'],
#  'man': ['манчестер-юнайтед', 'манчестер юнайтед', 'манчестер'],
#  'ure': ['манчестер-юнайтед', 'манчестер юнайтед', 'манчестер'],
#  'rags': ['манчестер-юнайтед', 'манчестер юнайтед', 'манчестер'],
#  'citizens': ['манчестер', 'манчестер-сити', 'манчестер сити'],
#  'blues': ['манчестер',
#   'челси',
#   'манчестер-сити',
#   'манчестер сити',
#   'бирмингем сити',
#   'бирмингем'],
#  'сити': ['манчестер', 'манчестер-сити', 'манчестер сити', 'ковентри сити'],
#  'city': ['манчестер', 'манчестер-сити', 'манчестер сити', 'ковентри сити'],
#  'шейхи': ['манчестер', 'манчестер-сити', 'манчестер сити'],
#  'голубая-луна': ['манчестер', 'манчестер-сити', 'манчестер сити'],
#  'луна': ['манчестер', 'манчестер-сити', 'манчестер сити'],
#  'gunners': ['арсенал'],
#  'пенсионеры': ['челси'],
#  'pensioners': ['челси'],
#  'таксисты': ['челси'],
#  'челски': ['челси'],
#  'птенцы-абрамовича': ['челси'],
#  'птенцы': ['челси'],
#  'абрамович': ['челси'],
#  'rentboys': ['челси'],
#  'вилла': ['астон-вилла', 'астон вилла', 'вилла'],
#  'villa': ['астон-вилла', 'астон вилла', 'вилла'],
#  'вилланы': ['астон-вилла', 'астон вилла', 'вилла'],
#  'villans': ['астон-вилла', 'астон вилла', 'вилла'],
#  'деревня': ['астон-вилла', 'астон вилла', 'вилла'],
#  'тюлени': ['астон-вилла', 'астон вилла', 'вилла'],
#  'reds': ['ливерпуль', 'ноттингем форест'],
#  'пеликаны': ['ливерпуль'],
#  'мерсисайдцы': ['ливерпуль'],
#  'скаузеры': ['ливерпуль'],
#  'ириски': ['эвертон'],
#  'toffees': ['эвертон'],
#  'чёрный-дрозд': ['эвертон'],
#  'дрозды': ['эвертон',
#   'бристоль роверс',
#   'вест бромвич альбион',
#   'вест бром',
#   'вест бромвич'],
#  'народный-клуб': ['эвертон'],
#  'горчиники': ['эвертон'],
#  'горемыки': ['эвертон'],
#  'the-clarets': ['бернли'],
#  'кларетовые': ['бернли'],
#  'шпоры': ['тоттенхэм-хотспур', 'тоттенхэм хотспур', 'тоттенхэм'],
#  'spurs': ['тоттенхэм-хотспур', 'тоттенхэм хотспур', 'тоттенхэм'],
#  'лилово-белые': ['тоттенхэм-хотспур', 'тоттенхэм хотспур', 'тоттенхэм'],
#  'lilywhites': ['тоттенхэм-хотспур', 'тоттенхэм хотспур', 'тоттенхэм'],
#  'горячие-головы': ['тоттенхэм-хотспур', 'тоттенхэм хотспур', 'тоттенхэм'],
#  'горячие': ['тоттенхэм-хотспур', 'тоттенхэм хотспур', 'тоттенхэм'],
#  'головы': ['тоттенхэм-хотспур', 'тоттенхэм хотспур', 'тоттенхэм'],
#  'евреи': ['тоттенхэм-хотспур', 'тоттенхэм хотспур', 'тоттенхэм', 'рома'],
#  'синеносые': ['бирмингем сити', 'бирмингем'],
#  'бродяги': ['блэкберн роверс',
#   'блэкберн',
#   'вулверхэмптон уондерерс',
#   'вулверхэмптон'],
#  'rovers': ['блэкберн роверс', 'блэкберн'],
#  'риверсайдцы': ['блэкберн роверс', 'блэкберн'],
#  'бараны': ['дерби каунти', 'дерби'],
#  'молотобойцы': ['вест хэм юнайтед', 'вест хэм'],
#  'молотки': ['вест хэм юнайтед', 'вест хэм'],
#  'hammers': ['вест хэм юнайтед', 'вест хэм'],
#  'хаммерс': ['вест хэм юнайтед', 'вест хэм'],
#  'айронс': ['вест хэм юнайтед', 'вест хэм'],
#  'железные': ['вест хэм юнайтед', 'вест хэм'],
#  'академия-футбола': ['вест хэм юнайтед', 'вест хэм'],
#  'академия': ['вест хэм юнайтед', 'вест хэм'],
#  'кокни': ['вест хэм юнайтед', 'вест хэм'],
#  'мальчики-кокни': ['вест хэм юнайтед', 'вест хэм'],
#  'wolves': ['вулверхэмптон уондерерс', 'вулверхэмптон'],
#  'wanderers': ['вулверхэмптон уондерерс', 'вулверхэмптон'],
#  'старое-золото': ['вулверхэмптон уондерерс', 'вулверхэмптон'],
#  'золото': ['вулверхэмптон уондерерс', 'вулверхэмптон'],
#  'рысаки': ['болтон уондерерс', 'болтон'],
#  'trotters': ['болтон уондерерс', 'болтон'],
#  'странники': ['болтон уондерерс', 'болтон'],
#  'белые': ['болтон уондерерс',
#   'болтон',
#   'фулхэм',
#   'реал мадрид',
#   'насьональ',
#   'насьональ'],
#  'помпи': ['портсмут'],
#  'pompey': ['портсмут'],
#  'турки': ['портсмут', 'депортиво', 'турция'],
#  'skates': ['портсмут'],
#  'tigers': ['халл сити', 'халл'],
#  'черные-коты': ['сандерленд'],
#  'black-cats': ['сандерленд'],
#  'коты': ['сандерленд'],
#  'макемс': ['сандерленд'],
#  'рокериты': ['сандерленд'],
#  'гончары': ['сток сити', 'стоук сити'],
#  'potters': ['сток сити', 'стоук сити'],
#  'латикс': ['уиган атлетик'],
#  'latics': ['уиган атлетик'],
#  'дачники': ['фулхэм'],
#  'cottagers': ['фулхэм'],
#  'whites': ['фулхэм'],
#  'коттеджеры': ['фулхэм'],
#  'форест': ['ноттингем форест'],
#  'лесные': ['ноттингем форест'],
#  'forest': ['ноттингем форест'],
#  'дворняги': ['барнсли'],
#  'tykes': ['барнсли'],
#  'святые': ['саутгемптон', 'саутхемптон', 'саутхэмптон'],
#  'saints': ['саутгемптон', 'саутхемптон', 'саутхэмптон'],
#  'пул': ['блэкпул'],
#  'pool': ['блэкпул'],
#  'seasiders': ['блэкпул'],
#  'мандарины': ['блэкпул'],
#  'tangerines': ['блэкпул'],
#  'зарянки': ['бристоль роверс'],
#  'robins': ['бристоль роверс'],
#  'baggies': ['вест бромвич альбион', 'вест бром', 'вест бромвич'],
#  'throstles': ['вест бромвич альбион', 'вест бром', 'вест бромвич'],
#  'вест': ['вест бромвич альбион', 'вест бром', 'вест бромвич'],
#  'бром': ['вест бромвич альбион', 'вест бром', 'вест бромвич'],
#  'west': ['вест бромвич альбион'],
#  'brom': ['вест бромвич альбион'],
#  'albion': ['вест бромвич альбион', 'вест бром', 'вест бромвич'],
#  'боярышники': ['вест бромвич альбион', 'вест бром', 'вест бромвич'],
#  'west-brom': ['вест бром', 'вест бромвич'],
#  'синие-птицы': ['кардифф сити', 'кардифф'],
#  'птицы': ['кардифф сити', 'кардифф'],
#  'лазурные-птицы': ['кардифф сити', 'кардифф'],
#  'лазурные': ['кардифф сити', 'кардифф'],
#  'синешейки': ['кардифф сити', 'кардифф'],
#  'bluebirds': ['кардифф сити', 'кардифф'],
#  'клинки': ['шеффилд юнайтед', 'шеффилд'],
#  'blades': ['шеффилд юнайтед', 'шеффилд'],
#  'sky-blues': ['ковентри сити'],
#  'боро': ['мидлсбро'],
#  'boro': ['мидлсбро'],
#  'смогги': ['мидлсбро'],
#  'smoggies': ['мидлсбро'],
#  'речники': ['мидлсбро'],
#  'красная-армия': ['мидлсбро'],
#  'тисайдцы': ['мидлсбро'],
#  'красная': ['мидлсбро'],
#  'сороки': ['ньюкасл юнайтед', 'ньюкасл'],
#  'magpies': ['ньюкасл юнайтед', 'ньюкасл'],
#  'тун': ['ньюкасл юнайтед', 'ньюкасл'],
#  'toon': ['ньюкасл юнайтед', 'ньюкасл'],
#  'джорди': ['ньюкасл юнайтед', 'ньюкасл'],
#  'чёрно-белые': ['ньюкасл юнайтед', 'ньюкасл', 'удинезе', 'ювентус'],
#  'пилигримы': ['плимут аргайл'],
#  'pilgrims': ['плимут аргайл'],
#  'зеленые': ['плимут аргайл', 'сент-этьен'],
#  'greens': ['плимут аргайл'],
#  'зеленая-армия': ['плимут аргайл'],
#  'green-army': ['плимут аргайл'],
#  'лебеди': ['суонси сити', 'суонси'],
#  'swans': ['суонси сити', 'суонси'],
#  'матросы': ['суонси сити', 'суонси'],
#  'jacks': ['суонси сити', 'суонси'],
#  'шершни': ['уотфорд'],
#  'hornets': ['уотфорд'],
#  'рога': ['уотфорд'],
#  'horns': ['уотфорд'],
#  'золотые-мальчики': ['уотфорд'],
#  'золотые': ['уотфорд'],
#  'мальчики': ['уотфорд'],
#  'жёлтая-армия': ['уотфорд'],
#  'желтая': ['уотфорд'],
#  'совы': ['шеффилд уэнсдей', 'шеффилд'],
#  'owls': ['шеффилд уэнсдей', 'шеффилд'],
#  'среда': ['шеффилд уэнсдей', 'шеффилд'],
#  'генуэзцы': ['сампдория', 'дженоа', 'геноа', 'бока хуниорс'],
#  'лигурийцы': ['сампдория', 'дженоа', 'геноа'],
#  'самп': ['сампдория'],
#  'дория': ['сампдория'],
#  'блючеркьятти': ['сампдория'],
#  'удинцы': ['удинезе'],
#  'фрриульцы': ['удинезе'],
#  'бьянконери': ['удинезе', 'ювентус', 'торино'],
#  'зебры': ['удинезе', 'ювентус', 'торино', 'шарлеруа'],
#  'чёрно-зелёные': ['сассуоло'],
#  'неаполитанцы': ['наполи'],
#  'кампанийцы': ['наполи'],
#  'партенопейцы': ['наполи'],
#  'адзурри': ['наполи'],
#  'маленькие-ослы': ['наполи'],
#  'маленькие': ['наполи'],
#  'ослы': ['наполи', 'кьево'],
#  'гадюки': ['интер'],
#  'biscioni': ['интер'],
#  'нерадзурри': ['интер', 'интер милан'],
#  'черно-синие': ['интер', 'интер милан'],
#  'клуб-побитых': ['интер', 'интер милан'],
#  'побитые': ['интер', 'интер милан'],
#  'любимчики': ['интер', 'интер милан'],
#  'ломбардийцы': ['интер', 'интер милан'],
#  'хвастуны': ['интер', 'интер милан'],
#  'хвастливые-миланцы': ['интер', 'интер милан'],
#  'хвастливые': ['интер', 'интер милан'],
#  'миланцы': ['интер', 'интер милан'],
#  'змеи': ['интер', 'интер милан'],
#  'интеристы': ['интер', 'интер милан'],
#  'мерда': ['интер', 'интер милан'],
#  'россонери': ['милан'],
#  'голландское': ['милан'],
#  'пристанище': ['милан'],
#  'голландское-пристанище': ['милан'],
#  'старики': ['милан'],
#  'гаечные-ключи': ['милан'],
#  'гаечные': ['милан'],
#  'ключи': ['милан'],
#  'бело-черные': ['ювентус'],
#  'старая-синьора': ['ювентус'],
#  'синьора': ['ювентус'],
#  'синьера': ['ювентус'],
#  'гоббы': ['ювентус'],
#  'госпожа-убийца': ['ювентус'],
#  'госпожа': ['ювентус'],
#  'пьемонтцы': ['ювентус'],
#  'юве': ['ювентус'],
#  'подруга-италии': ['ювентус'],
#  'подруга': ['ювентус'],
#  'невеста-италии': ['ювентус'],
#  'невеста': ['ювентус'],
#  'фиалки': ['фиорентина', 'тулуза'],
#  'флорентийцы': ['фиорентина'],
#  'тосканцы': ['фиорентина'],
#  'фиолетовые': ['фиорентина'],
#  'джеларосси': ['рома'],
#  'римляне': ['рома', 'лацио'],
#  'романиста': ['рома'],
#  'джаллароси': ['рома'],
#  'жёлто-красные': ['рома'],
#  'магическая-команда': ['рома'],
#  'магическая': ['рома'],
#  'пифагорейцы': ['кротоне'],
#  'акулы': ['кротоне'],
#  'лациале': ['лацио'],
#  'бело-небесно-голубые,бьянкочелести': ['лацио'],
#  'бьянкадзурри': ['лацио'],
#  'орлята': ['лацио', 'ницца'],
#  'фашисты': ['лацио'],
#  'молочники': ['парма'],
#  'пармезанцы': ['парма'],
#  'дети-герцога': ['парма'],
#  'герцога': ['парма'],
#  'ветчина': ['парма'],
#  'мясники': ['парма'],
#  'жёлто-синие': ['парма', 'верона'],
#  'крестоносцы': ['парма'],
#  'скуадра': ['торино'],
#  'граната': ['торино'],
#  'гранатовые': ['торино'],
#  'гранатовая-команда': ['торино'],
#  'грифоны': ['дженоа', 'геноа'],
#  'старые-шутники': ['дженоа', 'геноа'],
#  'старые': ['дженоа', 'геноа'],
#  'шутники': ['дженоа', 'геноа'],
#  'дельфины': ['пескара'],
#  'сардинцы': ['кальяри'],
#  'островитяне': ['кальяри', 'бастия'],
#  'сардинийцы': ['кальяри'],
#  'насриды': ['гранада'],
#  'грана': ['гранада'],
#  'греки': ['верона'],
#  'эллины': ['верона'],
#  'скалигеры': ['верона'],
#  'мастифы': ['верона'],
#  'петухи': ['бари',
#   'денизлиспор',
#   'атлетико',
#   'итуано',
#   'крб',
#   'clube de regatas brasil',
#   'паулиста',
#   'атлетико (минейро)',
#   'итуано'],
#  'кетчупс': ['лечче'],
#  'россоблу': ['болонья'],
#  'карбайонцы': ['реал овьедо'],
#  'carbayones': ['реал овьедо'],
#  'летающие-ослы': ['кьево'],
#  'джиалоблу': ['кьево'],
#  'летающие': ['кьево'],
#  'кьео': ['кьево'],
#  'жёлто-голубые': ['кьево'],
#  'джаллоблу': ['кьево'],
#  'ласточки': ['брешиа'],
#  'rondinelle': ['брешиа'],
#  'грифы': ['перуджа'],
#  'розанеро': ['палермо'],
#  'розово-чёрные': ['палермо'],
#  'аморанте': ['ливорно'],
#  'огурцы': ['реал бетис'],
#  'зеленушка': ['реал бетис'],
#  'бело-зелённые': ['реал бетис'],
#  'депор': ['депортиво'],
#  'ла-корунцы': ['депортиво'],
#  'галисийцы': ['депортиво'],
#  'галактикос': ['реал мадрид', 'реал'],
#  'сливочные': ['реал мадрид', 'реал мадрид', 'реал'],
#  'королевский-клуб': ['реал мадрид', 'реал'],
#  'бланкос': ['реал мадрид'],
#  'меренги': ['реал мадрид'],
#  'пастухи': ['реал мадрид'],
#  'мадридисты': ['реал мадрид'],
#  'овцы': ['реал мадрид'],
#  'сине-гранатовые': ['барселона'],
#  'гранатово-синие': ['барселона'],
#  'горячие-задницы': ['барселона'],
#  'барса': ['барселона'],
#  'блауграна': ['барселона'],
#  'каталонцы': ['барселона'],
#  'задницы': ['барселона'],
#  'ягодицы': ['барселона'],
#  'летучие': ['валенсия'],
#  'мыши': ['валенсия'],
#  'бэтмены': ['валенсия'],
#  'валенсийцы': ['валенсия'],
#  'чес': ['валенсия'],
#  'оранжевые': ['валенсия', 'голландия', 'нидерланды'],
#  'матрасники': ['атлетико мадрид', 'атлетико'],
#  'матрасы': ['атлетико мадрид', 'атлетико'],
#  'индейцы': ['атлетико мадрид', 'атлетико'],
#  'желтая-подводная-лодка': ['вильярреал'],
#  'подводная-лодка': ['вильярреал'],
#  'жёлтая-субмарина': ['вильярреал'],
#  'подводники': ['вильярреал'],
#  'баски': ['алавес', 'атлетик бильбао'],
#  'los-babazorros': ['алавес'],
#  'прославленные': ['алавес'],
#  'розовая-команда': ['алавес'],
#  'болеарцы': ['мальорка'],
#  'медузы': ['малага'],
#  'анчоусы': ['малага'],
#  'бетикос': ['бетис'],
#  'лягушки': ['леванты', 'леванте'],
#  'дятлы': ['кадис'],
#  'жёлтая-подводная-лодка': ['кадис'],
#  'пальмы': ['лас-пальмас'],
#  'жёлтые': ['лас-пальмас'],
#  'красные-перцы': ['мурсия'],
#  'пьяницы': ['тенерифе'],
#  'драконы': ['порту', 'америка', 'америка'],
#  'чёрные-овцы': ['омниворлд'],
#  'докеры': ['фейеноорд'],
#  'божьи': ['аякс'],
#  'суперфермеры': ['граафсхап'],
#  'superboeren': ['граафсхап'],
#  'суперорлы': ['го эхед', 'нигерия'],
#  'харлас': ['мускрон'],
#  'лиловые': ['андерлехт'],
#  'сиреневые': ['андерлехт'],
#  'шахтеры': ['генк'],
#  'газели': ['брюгге'],
#  'коалы': ['брюссель'],
#  'трехцветные': ['брюссель', 'франция'],
#  'ratten': ['харельбекке'],
#  'принцы': ['пари-сен-жермен', 'пари сен-жермен', 'псж'],
#  'парижане': ['пари-сен-жермен', 'пари сен-жермен', 'псж'],
#  'столичные': ['пари-сен-жермен', 'пари сен-жермен', 'псж'],
#  'морские-щуки': ['лорьян'],
#  'щуки': ['лорьян'],
#  'мерлузовые': ['лорьян'],
#  'кабаны': ['седан'],
#  'жирондинцы': ['бордо'],
#  'чертопо': ['нанси'],
#  'asnl': ['нанси'],
#  'монегаски': ['монако'],
#  'доги': ['лилль'],
#  'боксёры': ['лилль'],
#  'чернокожие': ['ренн'],
#  'бретонцы': ['ренн'],
#  'asse': ['сент-этьен'],
#  'stéphanois': ['сент-этьен'],
#  'гимнасты': ['ницца'],
#  "l'ogcn,красно-чёрные": ['ницца'],
#  'паладины': ['монпелье'],
#  'mhsc': ['монпелье'],
#  'кузнецы': ['геньон'],
#  'ночные': ['лозанна спортс'],
#  'кузнечики': ['грасхопперс'],
#  'желто-синие': ['батэ'],
#  'борисовчане': ['батэ'],
#  'батоны': ['батэ'],
#  'желто-зелёные': ['неман'],
#  'солигорцы': ['шахтер'],
#  'райо': ['райо вальекано'],
#  'молнии': ['райо вальекано'],
#  'красно-полосатые': ['райо вальекано'],
#  'тракторозаводцы': ['мтз-рипо'],
#  'мрази': ['мтз-рипо'],
#  'марсельцы': ['марсель'],
#  'провансальцы': ['марсель'],
#  'om': ['марсель'],
#  'арабы': ['марсель'],
#  'тёмно-бордовые': ['метц'],
#  'мессинцы': ['метц'],
#  'граулли': ['метц'],
#  'красненькие': ['осасуна'],
#  'рохильос': ['осасуна'],
#  'памплонцы': ['осасуна'],
#  'витебляне': ['витебск'],
#  'los-xeneizes': ['бока хуниорс'],
#  'бостерос': ['бока хуниорс'],
#  'los-bosteros': ['бока хуниорс'],
#  'кубковые-короли': ['бока хуниорс'],
#  'el-rey-de-copas': ['бока хуниорс'],
#  'сине-золотые': ['бока хуниорс'],
#  'los-millonarios': ['ривер плейт'],
#  'el-millo': ['ривер плейт'],
#  'ла-банда': ['ривер плейт'],
#  'la-banda': ['ривер плейт'],
#  'полосатые': ['ривер плейт'],
#  'курицы': ['ривер плейт'],
#  'цыплята': ['ривер плейт'],
#  'rojos': ['индепендьенте'],
#  'diablos': ['индепендьенте'],
#  'diablos-rojos': ['индепендьенте'],
#  'гордость-аргентины': ['индепендьенте'],
#  'el-orgulo-nacional': ['индепендьенте'],
#  'жёлто-чёрные': ['пеньяроль'],
#  'aurinegros': ['пеньяроль'],
#  'карбонерос': ['пеньяроль'],
#  'carboneros': ['пеньяроль'],
#  'маниас': ['пеньяроль'],
#  'manyas': ['пеньяроль'],
#  'мирасолес': ['пеньяроль'],
#  'mirasoles': ['пеньяроль'],
#  'больсос': ['насьональ', 'насьональ'],
#  'карманы': ['насьональ', 'насьональ'],
#  'bolsos': ['насьональ', 'насьональ'],
#  'трёхцветные': ['насьональ', 'гремио', 'сан паулу', 'насьональ', 'гремио'],
#  'tricolores': ['насьональ', 'насьональ'],
#  'albos': ['насьональ', 'насьональ'],
#  'больсильюдос': ['насьональ', 'насьональ'],
#  'bolsilludos': ['насьональ', 'насьональ'],
#  'мекао': ['америка', 'америка'],
#  'mecao': ['америка', 'америка'],
#  'dragao': ['америка', 'америка'],
#  'tricolor': ['гремио', 'гремио'],
#  'гаучос': ['гремио', 'гремио'],
#  'gauchos': ['гремио', 'гремио'],
#  'жу': ['жувентуд'],
#  'ju': ['жувентуд'],
#  'periquito': ['жувентуд', 'гойяс'],
#  'толстые': ['жувентуд'],
#  'жирные': ['жувентуд'],
#  'обжоры': ['жувентуд'],
#  'papo': ['жувентуд'],
#  'papado': ['жувентуд'],
#  'galo': ['атлетико', 'итуано', 'атлетико (минейро)', 'итуано'],
#  'альвинегро': ['атлетико', 'ботафого (рио-де-жанейро)', 'атлетико (минейро)'],
#  'бело-чёрные': ['атлетико',
#   'ботафого (рио-де-жанейро)',
#   'атлетико (минейро)'],
#  'alvinegro': ['атлетико', 'ботафого (рио-де-жанейро)', 'атлетико (минейро)'],
#  'рубронегро': ['итуано', 'атлетико', 'фламенго', 'итуано', 'атлетико'],
#  'rubronegro': ['итуано', 'атлетико', 'фламенго', 'итуано', 'атлетико'],
#  'ураганы': ['атлетико', 'атлетико'],
#  'furacao': ['атлетико', 'атлетико'],
#  'регатеано': ['крб', 'clube de regatas brasil'],
#  'regateano': ['крб', 'clube de regatas brasil'],
#  'пляжные': ['крб', 'clube de regatas brasil'],
#  'galo-da-praia': ['крб', 'clube de regatas brasil'],
#  'небожители': ['крузейро'],
#  'celestes': ['крузейро'],
#  'raposa': ['крузейро'],
#  'leao': ['ремо', 'форталеза'],
#  'azulinho': ['ремо'],
#  'колорадо': ['интернасьонал'],
#  'colorado': ['интернасьонал'],
#  'львы-с-барра': ['витория'],
#  'leao-da-barra': ['витория'],
#  'коралловые-аспиды': ['санта круз'],
#  'cobra-coral': ['санта круз'],
#  'кораллы': ['санта круз'],
#  'coral': ['санта круз'],
#  'аллигаторы': ['бразильенсе'],
#  'jacare': ['бразильенсе'],
#  'португальцы': ['португеза', 'португалия'],
#  'lusa': ['португеза'],
#  'galo-do-japi': ['паулиста'],
#  'трёхцветные-из-жундиая': ['паулиста'],
#  'tricolor-jundiaense': ['паулиста'],
#  'стальные-трёхцветные': ['форталеза'],
#  'tricolor-de-aco': ['форталеза'],
#  'clube-da-garotada': ['форталеза'],
#  'опоссумы': ['наутико'],
#  'timbu': ['наутико'],
#  'альвирубро': ['наутико'],
#  'бело-красные': ['наутико'],
#  'alvirubro': ['наутико'],
#  'лазурные-сойки': ['паранья'],
#  'gralha-azul': ['паранья'],
#  'трёхцветные-с-вила-капанема': ['паранья'],
#  'tricolor-da-vila-capanema': ['паранья'],
#  'porco': ['палмейрас'],
#  'вердао': ['палмейрас', 'коритиба', 'гама', 'гойяс'],
#  'verdao': ['палмейрас', 'коритиба', 'гама', 'гойяс'],
#  'альвиверде': ['палмейрас', 'коритиба', 'гама'],
#  'alviverde': ['палмейрас', 'коритиба', 'гама'],
#  'tigre': ['марилия'],
#  'тиграо': ['марилия'],
#  'тигрищи': ['марилия'],
#  'tigrao': ['марилия'],
#  'альвиселесте': ['марилия'],
#  'бело-небесные': ['марилия'],
#  'alviceleste': ['марилия'],
#  'командища': ['коринтианс'],
#  'timao': ['коринтианс'],
#  'корингао': ['коринтианс'],
#  'coringao': ['коринтианс'],
#  'мушкетёры': ['коринтианс'],
#  'mosqueteiro': ['коринтианс'],
#  'чемпион-чемпионов': ['коринтианс'],
#  'campeao-dos-campeaes': ['коринтианс'],
#  'белоногие': ['коритиба'],
#  'coxa': ['коритиба'],
#  'branca': ['коритиба'],
#  'кори': ['коритиба'],
#  'cori': ['коритиба'],
#  'фла': ['фламенго'],
#  'менго': ['фламенго'],
#  'fla': ['фламенго'],
#  'mengo': ['фламенго'],
#  'стервятники': ['фламенго'],
#  'urubu': ['фламенго'],
#  'рыбы': ['сантос'],
#  'peixe': ['сантос'],
#  'сантастико': ['сантос'],
#  'santastico': ['сантос'],
#  'азулао': ['сан каэтано'],
#  'azulao': ['сан каэтано'],
#  'макаки': ['понте прета'],
#  'macaca': ['понте прета'],
#  'трёхцветные-из-сан': ['сан паулу'],
#  'паулу': ['сан паулу'],
#  'tricolor-paulista': ['сан паулу'],
#  'фого': ['ботафого (рио-де-жанейро)'],
#  'бота': ['ботафого (рио-де-жанейро)'],
#  'fogo': ['ботафого (рио-де-жанейро)'],
#  'bota': ['ботафого (рио-де-жанейро)'],
#  'огонище': ['ботафого (рио-де-жанейро)'],
#  'fogao': ['ботафого (рио-де-жанейро)'],
#  'одинокая-звезда': ['ботафого (рио-де-жанейро)'],
#  'estrela-solitaria': ['ботафого (рио-де-жанейро)'],
#  'выдающиеся': ['ботафого (рио-де-жанейро)'],
#  'блестящие': ['ботафого (рио-де-жанейро)'],
#  'glorioso': ['ботафого (рио-де-жанейро)'],
#  'гамао': ['гама'],
#  'gamao': ['гама'],
#  'эсмералдиньо': ['гойяс'],
#  'изумрудные': ['гойяс'],
#  'esmeraldinho': ['гойяс'],
#  'морские': ['хайдук'],
#  'ассы': ['хайдук'],
#  'портные': ['вартекс', 'вартекс'],
#  'поэты': ['загреб', 'загреб'],
#  'цыгане': ['црвена звезда', 'црвена', 'црвена звезда'],
#  'романтики': ['офк белград', 'офк-белград'],
#  'могильщики': ['партизан', 'партизан'],
#  'витязи': ['обилич', 'обилич'],
#  'канаринья': ['бразилия', 'бразилия'],
#  'черные-буйволы': ['краснодар'],
#  'буйволы': ['краснодар'],
#  'кастраты': ['краснодар'],
#  'магниты': ['краснодар'],
#  'черно-зеленые': ['краснодар'],
#  'альбиселеста': ['аргентина', 'аргентина'],
#  'лазурная-эскадра': ['италия'],
#  'скуадра-адзурра': ['италия'],
#  'макаронники': ['италия'],
#  'итальянцы': ['италия'],
#  'три-короны': ['швеция'],
#  'тре-крунер': ['швеция'],
#  'викинги': ['швеция'],
#  'шведы': ['швеция'],
#  'соккеруз': ['австралия', 'австралия'],
#  'кенгуру': ['австралия', 'австралия'],
#  'гуарани': ['парагвай', 'парагвай'],
#  'рубины': ['рубин'],
#  'рубиновые': ['рубин'],
#  'казанцы': ['рубин'],
#  'татары': ['рубин'],
#  'сибирцы': ['сибирь'],
#  'островные-львы': ['авай'],
#  'leao-da-ilha': ['авай'],
#  'васкао': ['васко да гама'],
#  'vascao': ['васко да гама'],
#  'гиганты-с-холма': ['васко да гама'],
#  'gigante-da-colina': ['васко да гама'],
#  'треска': ['васко да гама'],
#  'bacalhau': ['васко да гама'],
#  'мальтийский-крест': ['васко да гама'],
#  'clube-da-cruz-de-malta': ['васко да гама'],
#  'рубашки': ['васко да гама'],
#  'os': ['васко да гама'],
#  'camisas': ['васко да гама'],
#  'pretas': ['васко да гама'],
#  'голубые-львы': ['динамо (загреб)'],
#  'морские-ассы': ['хайдук'],
#  'аргентинцы': ['аргентина'],
#  'австралийцы': ['австралия'],
#  'ацтеки': ['мексика'],
#  'мексиканцы': ['мексика'],
#  'инки': ['перу'],
#  'чарруас': ['венесуэла'],
#  'янки': ['сша'],
#  'американцы': ['сша'],
#  'америкосы': ['сша'],
#  'фараоны': ['египет'],
#  'египтяне': ['египет'],
#  'неукротимые-львы': ['камерун'],
#  'камерунцы': ['камерун'],
#  'янычары': ['турция'],
#  'бафана-бафана': ['юар'],
#  'африканцы': ['юар'],
#  'одинокая': ['либерия'],
#  'звезда': ['либерия'],
#  'нигерийцы': ['нигерия'],
#  'голландцы': ['голландия', 'нидерланды'],
#  'нидерландцы': ['голландия', 'нидерланды'],
#  'сырники': ['швейцария'],
#  'швейцарцы': ['швейцария'],
#  'норманы': ['норвегия'],
#  'норвежцы': ['норвегия'],
#  'лягушатники': ['франция'],
#  'мушкетеры': ['франция'],
#  'петушки': ['франция'],
#  'французы': ['франция'],
#  'французики': ['франция'],
#  'черные-звезды': ['гана'],
#  'слоны': ["кот-д'ивуар"],
#  'банкиры': ['люксембург'],
#  'люксембургцы': ['люксембург'],
#  'пентакампеоны': ['бразилия'],
#  'кудесники-мяча': ['бразилия'],
#  'желтые': ['бразилия'],
#  'горожане-рио': ['бразилия'],
#  'дие-маншафт': ['германия'],
#  'футбольные': ['тринидад и тобаго'],
#  'воины': ['тринидад и тобаго'],
#  'леопарды': ['конго'],
#  'датский-динамит': ['дания'],
#  'датчане': ['дания'],
#  'валлийцы': ['уэльс'],
#  'красные-драконы': ['уэльс'],
#  'вареные-ящерицы': ['уэльс'],
#  'бельгийцы': ['бельгия'],
#  'жгучие-парни': ['хорватия'],
#  'хорваты': ['хорватия'],
#  'ковбои': ['пуэрто-рико'],
#  'пуэрориканцы': ['пуэрто-рико'],
#  'рэгги-бойз': ['ямайка']}

# %%
df = pd.read_csv('result_tar.gz', compression='gzip', sep='\t', error_bad_lines=False)

# %%
df = df.drop(["url", "video_url", "source_name", "author_name"], axis=1)
df = df.dropna()
df = df.drop_duplicates()
df = df.reset_index(drop=True)

# %%
import re
def which_language (text):
    if bool(re.search('[\u0400-\u04FF]', text)) == True:
        return 'russian'
    else:
        return 'english'

# %%
lang=[]
for i,text in enumerate(df['result.tsv'].values): 
    lang.append(which_language(str(text)))

# %%
df['Language'] = lang

# %%
grouped=df.groupby('Language')

# %%
for name, group in grouped: 
    if name == 'english': 
        english = group.drop('Language',axis=1) 
    else: 
        russian = group.drop('Language',axis=1)

# %% [markdown]
# ### листдикт

# %%
count = 0
for i, prediction in enumerate(russian['result.tsv']):
    for word in prediction.split():
        word = word.strip(punctuation)
        word = word.lower()
        if word and word not in punctuation:
            try:
                if word in dict2.keys():
                    for item in dict2[word]:
                        #print(item)
                        if item == russian['team_of_season_1_name_in_russian'][i].lower() or item == russian['team_of_season_2_name_in_russian'][i].lower():
                            #print(word, item, russian['team_of_season_1_name_in_russian'][i], russian['team_of_season_2_name_in_russian'][i])
                            count += 1
                        
            except:
                pass

# %%
print(count)
# Out:
# 3069

# %%
russian.describe()
# Out:
#        result.tsv       odd tip_name bookmaker_name      match_date_time  \
# count      595931  595931.0   595931         595931               595931
# unique     535424    1826.0    12971             34                 7050
# top            Да       1.7       П1       1xСтавка  2019-04-11 19:00:00
# freq         1591    5387.0    89547         213367                 3536
#
#        league_name_in_russian team_of_season_1_name_in_russian  \
# count                  595931                           595931
# unique                    288                             3773
# top              Премьер-лига                        Ливерпуль
# freq                    63171                             9043
#
#        team_of_season_2_name_in_russian
# count                            595931
# unique                             3730
# top                           Ливерпуль
# freq                              10999
